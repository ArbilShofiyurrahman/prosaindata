# %% [markdown]
# # Topic Modelling

# %% [markdown]
# ## Crawling Data Dari Komentar Youtube

# %% [markdown]
# Program ini bertujuan untuk melakukan pengambilan data komentar pada sebuah video YouTube menggunakan Youtube Data API v3. Sebelum menggunakan program ini, pastikan bahwa layanan Youtube Data API telah diaktifkan dan API Key sudah di-generate.
#
# Jika Anda belum memiliki API Key, berikut adalah langkah-langkah untuk memperolehnya:
#
#
#
# 1.   Login ke Google Developer Console (https://console.developers.google.com/) dengan akun Google Anda.
#
# 2.   Buatlah project baru dan isi informasi yang diminta.
# 3.   Aktifkan layanan API pada halaman project dan cari Youtube Data API v3.
# 4.   Buat kredensial agar API tersebut dapat digunakan. Klik tombol "Create Credential" dan lengkapi form yang diminta.
#
# Anda dapat mengakses/melihat API Key pada tab Credentials di dashboard.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import library
import pandas as pd
from googleapiclient.discovery import build
import numpy as np
from string import punctuation
import re
import nltk

# %%
#Membuat function untuk crawling data
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:
		
		# extracting required info
		# from each result object
		for item in video_response['items']:
			
			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])
			
			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:
					
					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']
					
					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'], 
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyAV3tFWjw2nnIOtVL3u0cTLQiTJ7k59V_U'

# url video =https://youtu.be/4F1xyLpwxsw
video_id = "4F1xyLpwxsw" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2023-05-10T12:06:58Z',
#   'Ahmad Husen',
#   'Tapi elit politik seperti cak imin erlangga susah untuk memberi tikat untuk mafud karna dah busuk',
#   0],
#  ['2023-05-10T12:05:21Z', 'Ciung Wanara', 'Ngabalin cocok untk ganjar', 0],
#  ['2023-05-10T12:05:21Z',
#   'Ahmad Husen',
#   'Jika alloh meridhoi kita berharap Prabowo dengan mafud MD dulu memang kita dukung jokowi tapi insa alloh dukung prabowo mafud',
#   0],
#  ['2023-05-10T12:04:48Z',
#   'Nisa Nisa',
#   'Setiap kita akan mempertanggung jawabkan pilihan kita masing2<br>Jika pilihan kita yg kita pilih amanah,jujur dan adil (bersyukurlah)<br>Tapi...jika pilihan kita,tidak amanah,tidak jujur dan tidak adil kepada Rakyat dan berdusta <br>Maka seluruh pendukungnya akan ikut menanggung dosa2 pilihannya selama dia menjabat<br>Semoga Allah SWT...menolong indonesia dari calon2 yg pendusta.Aamiin',
#   0],
#  ['2023-05-10T11:41:14Z',
#   'Deny Saputro',
#   'Siapapun Capresnya, Wakilnya tetap PAK JENDERAL FREDY NUMBERI',
#   0],
#  ['2023-05-10T10:46:11Z',
#   'ARIEF PRASETYAWAN',
#   'Siapa capres yg mengganden pak mahfud siap kita dukung dan perjuangkan💪💪',
#   0],
#  ['2023-05-10T10:41:24Z',
#   'shasa flower',
#   'BENER JUGA PERKIRAAN KEBANYAKAN MASYARAKAT, <br>DENGAN NYINYIRIN PAK JOKOWI, TERNYATA JUSUF KALLA ADA MAUNYA.. 😂<br>PINGIN JADI WAKIL PRESIDEN .!!<br>EMANG BISA ?  UDAH 2 KALI JADI WAPRES.. ?!.',
#   0],
#  ['2023-05-10T10:27:36Z',
#   'Pantang menyerah',
#   'SINGKAT NYA GINI. JANGAN PILIH PETUGAS PARTAI APALAGI YG HOBINYA NONTON FILM P*RNO 😢 JAGA INDONESIA DARI KERUSAKAN MORAL 💪🇮🇩',
#   0],
#  ['2023-05-10T10:03:47Z', 'Inisial A', 'Musiknya mantap min...', 0],
#  ['2023-05-10T09:57:03Z', 'Orna 13', 'ANIES -SAID AQIL SIRADJ', 0],
#  ['2023-05-10T09:39:43Z',
#   'Buzarman Buzarman',
#   'Probowo vs Mahfud MD. Utk NKRI masa depan supaya negara aman rakyat makmur Dimata dunia dihargai.',
#   1],
#  ['2023-05-10T09:31:22Z',
#   'Danny Rizky',
#   'NU menjaga negeri ini dari keterpecahan. Wajar bila capres pemersatu bangsa (PRABOWO) memilih nahdliyin (MAHFUD) sebagai cawapresnya.',
#   1],
#  ['2023-05-10T09:31:11Z',
#   'Agus Yulianto',
#   'GANJAR PRABOWO <br>VS<br>ANIS AHY',
#   0],
#  ['2023-05-10T09:07:44Z',
#   'sahnun sahnun',
#   'Siapa saja capres yg bergabung dg TGB,insaalloh sukses',
#   0],
#  ['2023-05-10T09:01:53Z',
#   'sahnun sahnun',
#   'Jg pilih dr jawa saja klu dr jawa,indo ngak maju2 pilihlah luar jawa,malah dr luar jawa yg berkualitas,jawa banyak mapia cap gayung',
#   0],
#  ['2023-05-10T08:56:23Z',
#   'Slamet Buchori',
#   'Pak Ganjar di dampingi cawapres manapun tetap saja akan kalah ...karena PDIP sekarang ini tak punya jago yg handal ...lain pada pilpres 2014 dan 2019 partai moncong putih mempunyai jago yang hebat daya magnetnya tinggi yaitu presiden kita pak Joko Widodo...tapi sekarang capresnya di poles model apapun dng berbagai pencitraan elektabilitasnya tetap di bawah pak Prabowo dan pak Anis ...saatnya 2024 PDIP turun tahta jadi partai oposisi seperti yg sudah sudah 10 tahun yg lalu',
#   0],
#  ['2023-05-10T08:49:41Z',
#   'sahnun sahnun',
#   'Penguasa jg jurang,klu Tgb masuk cawapres akan tengelam yg mucul adalah TGB',
#   0],
#  ['2023-05-10T08:24:30Z',
#   'dede ramdan ramdan',
#   'Yang pantas cawapres adalah antara ridwan kamil dan sandiaga uno',
#   0],
#  ['2023-05-10T07:56:42Z', 'Rita Sumbawati', 'Anis Khofifah', 0],
#  ['2023-05-10T12:19:12Z', 'James Bond', 'Anies-ahok😅😅😅', 0],
#  ['2023-05-10T07:50:50Z',
#   'Willoughbia elmerii',
#   'Yang jadi kunci kemenangan itu siapa yang beri garansi menghukum mati koruptor.  Yang ndak berani cuma tukang ngibul atau emang berencana korupsi.',
#   0],
#  ['2023-05-10T07:16:54Z',
#   'PUTRA TUNGGAL CHANNEL',
#   'Mahfud MD, erick thohir, said aqil...lainnya gak masok.',
#   1],
#  ['2023-05-10T07:04:20Z',
#   'martin bakhtiar',
#   'Mana ada cawapres jadi kunci kemenangan klu penambal kemenangan bisa namanya Juga ban serep',
#   0],
#  ['2023-05-10T06:42:59Z',
#   'Adi Harsono',
#   'Calon cawapresnya ga ada yg bisa di pilih,',
#   0],
#  ['2023-05-10T06:36:32Z', 'Suwarno', 'GS cukup Ganjar Sandi', 0],
#  ['2023-05-10T06:33:57Z',
#   'Meiza Harminda',
#   'Salah....bkn cawapres tpi serangan fajar aplop putih........',
#   0],
#  ['2023-05-10T06:26:15Z', 'Hadi Es Pe', 'Mahfud MD Jujur Berani tegas', 0],
#  ['2023-05-10T06:25:46Z', "i'm nana", 'Anis-Ahy', 0],
#  ['2023-05-10T06:25:41Z',
#   'Umar said Basalamah',
#   'Anis mendunia dan menggemparkan di lndonesia,presiden yg di psnggil rakyat nya di seluruh lndonesia,Dan punya magnit terbukti,berduyun2 mendaftarkan diri menjadi relawan yg benar2 rela tanpa uang,ini yg sangat mengagumkan,jadi,ya karna kekuatan besar,murni dan semua relawan bertegad ingin perubahan rasa nya sulit sndaikata kpu bawaslu mai curang soal nya kekuatan besar berduyun2 mengalir utk menjadi relawan Anis,kita berharap kpu netral,kalau tdk sangat berbahaya',
#   0],
#  ['2023-05-10T12:17:59Z', 'James Bond', 'Anies juara 3😂😂😂', 0],
#  ['2023-05-10T06:07:14Z',
#   'Yulia Si',
#   'Siapa yg se7 Pak Mahfud MD Jadi CaWaPres Pak Ganjar Pranowo??👍🇲🇨',
#   0],
#  ['2023-05-10T06:03:45Z', 'Agus Agus', 'P.mahfud', 0],
#  ['2023-05-10T05:59:28Z',
#   'Asray 2013',
#   'halah basi ujung2nye Ganjar sama Erik Tohir Si Anak Cina Peranakan<br>biji peler',
#   0],
#  ['2023-05-10T05:58:43Z',
#   'Martin tohoma',
#   'Mahfud md sgt layak cawapres ganjar...',
#   2],
#  ['2023-05-10T05:54:48Z',
#   'Wika Nugraha',
#   'Pilihlah presiden yang membawa perubahan........',
#   0],
#  ['2023-05-10T05:52:53Z',
#   'Wika Nugraha',
#   'Pak oke capres memang sudah terbukti gubernur dki mempunyai karya nyata dan cawapres kesepakatan koalisi partai bagaimanapun harus pilihan Anis Baswedan .',
#   1],
#  ['2023-05-10T12:10:52Z',
#   'James Bond',
#   'Hsl jual mayat dpt kursi gubernur 😅😅😅',
#   0],
#  ['2023-05-10T05:48:59Z',
#   'emy atika',
#   'Ma&#39;af deh klu said Aqil Siroj dan cak Imin janganlah di promosikan nanti jadi apa negara Indonesia ini... klu dua orang ini saya sekeluarga tidak akan nyoblos siapapun capresnya jika cawapresnya salah satu antara dua nama tsb',
#   0],
#  ['2023-05-10T05:46:04Z',
#   'mochamad rodli',
#   'cawapres nya kemungkinan dr NU.. Ganjar butuh suara NU utk mempertahankan suara NU yg memilih Jokowi kemaren..kalo Anies dan Prabowo jelas mau ambil suara NU yg dlu dilabuhkan ke Jokowi 2019 lalu..',
#   0],
#  ['2023-05-10T05:45:09Z',
#   'Muslimin Qosim',
#   'Yg kinerjanya bagus, berhsl memimpin, teguh pendirian tdk plin plan.',
#   0],
#  ['2023-05-10T05:41:01Z',
#   'User Samsung',
#   'Caplin kok sibuk bgt, apa ngak tau rakyat waras muntah melihat makhluk itu.',
#   0],
#  ['2023-05-10T05:31:59Z',
#   'Edi Cahyono',
#   'Khofifah orang yg paling Cocok untuk Cawapres Prabowo. Karena Jawa Timur. Kantongnya PKB.',
#   0],
#  ['2023-05-10T05:31:58Z',
#   'Kristina Kiki Popov',
#   '🇲🇨 🦅 ... ❤ Prabowo, 😍 .. 🥰',
#   0],
#  ['2023-05-10T05:27:18Z',
#   'Agus Sugiarto',
#   'P.Mahfud cawapres yg tepat dan potensial dipasangkan P.Ganjar beliau sederhana, tau kondisi rakyat kecil,intelektual, cerdas, sangat berpengalaman di birokrasi,anggota dewan, yudikatif,konstitusi,berani thd pemberantasan TPPU,korupsi, dg dmkian rakyat akan lebih sejahtera.',
#   4],
#  ['2023-05-10T05:24:03Z',
#   'Pak Bas',
#   'Pak Ganjar siapapun cawapresnya insyaalloh menang total.prediksi saya pribadi bisa salah bisa benar.yg sudah sudah jarang meleset prediksi saya.',
#   0],
#  ['2023-05-10T05:21:52Z',
#   'Muktohar Gendut',
#   'COBA CAPLIN GAK USAH NYINYIRIN PRESIDEN  NYAPRES SENDIRI AJA LAKUBPABGAK',
#   0],
#  ['2023-05-10T05:21:07Z',
#   'Dadang Hawari',
#   'Ganjar duet Prabowo wes dijamin 1 putaran menang di pilpres 2024...nek pengen menang',
#   0],
#  ['2023-05-10T05:20:12Z',
#   'Muhammad Rafi',
#   'Pak Anis &amp; pak Mahmud MD,,pilihan kami.sumut.',
#   0],
#  ['2023-05-10T05:11:12Z',
#   'Rits nya Rits',
#   'Neng anne bupati purwakarta tidak nyalonin jd presiden kah..',
#   0],
#  ['2023-05-10T05:01:20Z',
#   'Eka Yulianto',
#   'Ganjar - Prabowo.<br>Terserah mau di bolak balik.<br>Dah lah, males rame2 lagi.<br>Ini aja lapangan kerja sudah susah, politik terus, kapan rakyat kecil dapat kerja? <br>Kami orang kecil gak ngurus kepentingan para Raja..<br>Mereka para Raja nganggur 10 th pun masih bisa seneng2, kita orang kecil 1 th aja nganggur juga positif bangkrut.',
#   0],
#  ['2023-05-10T05:00:18Z', 'Nyoman Premi', 'Cawapres nya Prof  Mahfud 👍🏻👍🏻', 2],
#  ['2023-05-10T04:55:09Z',
#   'hasbi jaenudin',
#   '.Bolot Nurhadi ...serasa Gus Samsudin kurang kuat suara di kalangan milinium mininimalis z 5.0 .j.I❤ Indonesia <br>Gus Samsudin bisa saja menang jika pesulap merah ga licik di pilpres 19 ...02 nurhadi Aldo yang dapet',
#   0],
#  ['2023-05-10T04:54:01Z',
#   'low profile',
#   'Kubu rival anies baswedan pasti menginginkan anies duetnya sama AHY.. biar efek elektoral gak naik.<br>Bukan bermaksud meremehkan AHY.. tp kualitas kepemimpinan AHY harus di uji dulu di level mentri..',
#   0],
#  ['2023-05-10T04:52:22Z',
#   'Iwan Zahazsra',
#   'Siapapun wakilnya tetap coblos Pak Ganjar Pranowo,,,,,',
#   2],
#  ['2023-05-10T04:51:59Z',
#   'Dwi Budi',
#   'Jgn LUPA Cawapres sama Petugas RAKYAT  yg Amanah !!',
#   0],
#  ['2023-05-10T04:51:35Z',
#   'Rindu',
#   'TH 2024 ,. .INSA ALLAH PK PRABOWO SUBIANTO TERPILIH PRESIDEN RI KE 8 ,...SUDAH JATAHNYA ...TANDA2 ALAM SUDAH TERLIHAT',
#   0],
#  ['2023-05-10T04:47:39Z', 'Anak Sabu', 'GP- Mahmud Md❤', 0],
#  ['2023-05-10T04:45:59Z',
#   'Samuel Rizal',
#   'Prabowo-mahfudz is the best 2024',
#   3],
#  ['2023-05-10T04:45:42Z',
#   'Subhan Iam',
#   'Khofifah,Eric Thohir dan Mahfud MD',
#   0],
#  ['2023-05-10T04:43:59Z', 'Adi Sutrisno', 'Hanta nggedebuuuuuus ...', 0],
#  ['2023-05-10T04:42:25Z', 'Moh Kirom', 'Pak Mahfud MD vs pak Anis', 1],
#  ['2023-05-10T04:38:04Z',
#   'Ahmad Rohadi',
#   'Pak anis cerdas mas ahy tegas mantap perobahan',
#   2],
#  ['2023-05-10T04:36:33Z',
#   'Hay Manis',
#   'Kadrun Kalau Merasa Benaarr Merasa Suci Tidak Perlu TAKUT ENDORSE di Ketawain Cebong Sekolam tuuch.',
#   0],
#  ['2023-05-10T04:34:56Z',
#   'Agus sulistyo',
#   'Pdip ngusung GP sbg Capres, kelak Cawapresnya si Tuan maha Putri...( jika sukses ),  ditengah jalan, Cawapresnya bakal &quot;&quot;menyodok&quot;&quot; Demikianlah skenarionya !! 😁😀',
#   0],
#  ['2023-05-10T04:32:57Z',
#   'Boy Andiek',
#   'Sumpah...Aku malah Seneng Intro Musiknya😎🔥🔥🔥',
#   2],
#  ['2023-05-10T04:32:51Z',
#   'Asim 85',
#   'Anis Ridwan Kamil,,cocok buat 2024,,Takbir Allohu Akbar',
#   0],
#  ['2023-05-10T04:29:56Z', 'Kotrul Goist', 'Gatot Nurmantyo ☝️', 2],
#  ['2023-05-10T04:29:32Z',
#   'New Normal',
#   'Nggedabrus si hantayuda cocok jadi cawaores Kakek Sugiono',
#   0],
#  ['2023-05-10T04:29:16Z',
#   'Priyo Priyono',
#   'Kalau saja pak Gatot Nurmantyo masuk sebagai cawapres pak Anies Baswedan menurut saya sangat ideal dan cocok untuk Indonesia',
#   0],
#  ['2023-05-10T04:27:10Z',
#   'Bianda Fiarty',
#   'Aah....ga musti dari NU....rakyat dah semakin cerdas...kepada siapa wewenang itu dititipkan..',
#   0],
#  ['2023-05-10T04:26:03Z', 'Rizal Rizal', 'Bpk mahfud md sangat cocok', 3],
#  ['2023-05-10T04:24:52Z',
#   'New Normal',
#   'Siapapun cawapresnya PDIP tetaplah itu wadah komunis',
#   1],
#  ['2023-05-10T04:24:27Z',
#   'Elisabeth Tangaran',
#   'Anis AHY pasanga muda masih pres AHY seluruh indonesia tahu ketum demokrat anak SBY kalau yang lain walaupun pejabat daerah tapi tidak semua tahu siapa dia ia kan.',
#   1],
#  ['2023-05-10T04:21:28Z',
#   'Uwe Miskanto',
#   'Harus nya yang punya sosok kaya Ma,ruf Amin jarang bicara tapi kinerja Bagus..',
#   1],
#  ['2023-05-10T04:19:05Z',
#   'Salim Salim',
#   'Anies Khofifah Indar sangat cocok di 2024, saya setuju, salam dari indobatim',
#   0],
#  ['2023-05-10T04:14:01Z',
#   'Abdul Azis Basam',
#   'KENAPA YA LENBAGA SURVEI TDK MENSURVEI BP MAHFUD MD ?????',
#   3],
#  ['2023-05-10T12:17:50Z',
#   'Abdul Azis Basam',
#   '@James Bond .oh begitu ya.kanpengguna  hp banyak, Apa kita yg make hp termasuk org Elit?',
#   0],
#  ['2023-05-10T12:13:04Z',
#   'James Bond',
#   'Mahfud cuma dikenal di kalangan elit klo wong cilik byk yg blm kenal',
#   0],
#  ['2023-05-10T05:27:59Z',
#   'Hasan Nudin',
#   'Survei kan hanya pesanan para elit...jadi klo gx ada yg pesan gx bakal di survei ataupun survei ny rendah🤣🤣🤣',
#   0],
#  ['2023-05-10T04:13:37Z', 'rosi trans', 'Anis-Ahy top', 1],
#  ['2023-05-10T04:13:02Z',
#   'Bro Doddy',
#   'yang lebih pas ya Prabowo-Mahfud MD kalau Ganjar-Mahfud MD kasihan Mahfud MD 😂😂😂',
#   5],
#  ['2023-05-10T08:00:25Z',
#   'Daniel candera Candara',
#   'betul, kyny pak MD lebih doyan( ideal), berpasangan dgn pak PS',
#   0],
#  ['2023-05-10T04:09:26Z',
#   'cupitong',
#   'Kalo bisa diusul sesekali cawapres dari non muslim dong ini kan negara bukan 1 agama dan masih banyak orang pintar dan jujur dari non muslim',
#   0],
#  ['2023-05-10T04:06:52Z',
#   'Habib Mustova',
#   'akhirx kluar jga prediksiku ini.🤣🤣🤣smua rebutanx org NU..spa yg mndahuluix dia yg pling bnyak pndapatan suarax NU🤣🤣🤣krna org NU gk usah disuruh di saat sdh ada jagoan dri glonganx sdh psti akan manut🤣🤣🤣',
#   0],
#  ['2023-05-10T04:05:44Z', 'Siwi Handaya', 'PRABOWO + MAHFUDZ MD', 3],
#  ['2023-05-10T04:04:12Z',
#   'Pendowo Limo',
#   'Prabowo - eric tohir sangat pas 2024',
#   0],
#  ['2023-05-10T04:03:13Z',
#   'iseng 87 chanel',
#   'Klw Anis Mahfud MD pasti kuat',
#   0],
#  ['2023-05-10T03:58:36Z', 'Robby Hadiansyah', 'ANIES-AHY 2024❤', 0],
#  ['2023-05-10T03:58:35Z',
#   'Brodidi Bro',
#   'Bodoh  ..kemenngan itu ditangan rakyat..coba rakyat golput semua bisa apa mereka..',
#   0],
#  ['2023-05-10T03:58:06Z', 'People Grunge', 'Mahfud MD cawapres terbaik 👍', 2],
#  ['2023-05-10T03:57:34Z',
#   'garudarevolution',
#   'Saya coblos yang ada pro machfud nya, kecuali pak anis',
#   0],
#  ['2023-05-10T03:54:02Z',
#   'Mansun Bdl',
#   'Carilah cawapres yg mempunyai kompetensi, kontribusi buat bangsa dan yg sudah teruji, terbukti nyata gimana ....???',
#   0],
#  ['2023-05-10T03:53:10Z', 'Zulfan Syah', 'Prabowo-airlangga', 0],
#  ['2023-05-10T03:52:36Z',
#   'angel phone',
#   'Kalau bagi saya siapapun jadi presiden Indonesia jangan bertumpuk utang dan bertumpuk korupsi dan jangan sampai jadi boneka-boneka partai politik begitu juga kepada anggota DPR RI sok jago/ preman berkualitas',
#   3],
#  ['2023-05-10T03:47:43Z',
#   'Rachmad Santoso',
#   'NO GENJER PETUGAS PARTAI PDI.P ANTI ISLAM MUNAFIK DAJALL... PARTAI PDI.P ANTI ISLAM MUNAFIK KATA NYA TIDAK BUTUH CARI SUARA KE UMAT ISLAM.. TAPI GENJER CAPRES NYA CARI SIMPATI SAFARI POLITIK IDENTITAS KE ULAMA DAN PESANTREN UMAT ISLAM.. <br>HARAM LAKNAT AZAB ALLOH MEMILIH GENJER PETUGAS PARTAI PDI.P MUNAFIK DAJALL DI PILPRES 2024... HADEH',
#   0],
#  ['2023-05-10T03:47:35Z', 'Muhammad Firdaus Ismail', 'Anies Mahfud MD', 0],
#  ['2023-05-10T03:45:29Z', 'Mikael Tade Hae', 'Prabowo-Mahfud', 7],
#  ['2023-05-10T04:15:19Z', 'Abdul Azis Basam', 'Se7 Bangat', 0],
#  ['2023-05-10T03:41:57Z',
#   'Danil Danil 123',
#   'Hanya Mahfud MD &amp; Khofifah yg di kader Gusdur krn Said Aqil Siroj &amp; Cak Imin padagang NU di era gusdur &amp; jokowi',
#   10],
#  ['2023-05-10T03:41:32Z', 'butuh modal', 'Anies ahy', 0],
#  ['2023-05-10T03:41:31Z', 'Jaelani ALBAROKAH', 'Anies Ahy insa alloh', 0],
#  ['2023-05-10T03:41:16Z',
#   'People Grunge',
#   'cawapres nya Prabowo adalah Mahfud MD 👍👍',
#   5],
#  ['2023-05-10T03:40:26Z',
#   'mysyamsir siregar',
#   '🇮🇩🇮🇩🇮🇩 - KITA RAKYAT PRIBUMI NASIONALIS TULEN WAJIB HUKUMNYA UNTUK MENJADI PRESIDEN DI NKRI INI ... BUKAN DARI KETURUNAN KOMUNIS ARAB YAMAN SELATAN ... MERDEKA ATAU TETAP DIJAJAH / DIPERBUDAK / DITINDAS / DIBODOHI OLEH DAJJAL KADRUN DAN NASDRUN KETURUNAN KOMUNIS ARAB YAMAN SELATAN DI NUSANTARA INI ... ( KLIK DI GOOGLE , KEMUDIAN KETIK , YAMAN HABIB KOMUNIS YAHUDI ... DAN BACA PASTI KAU CERDAS OK ) INI ADALAH FAKTA 🇮🇩🇮🇩🇮🇩 Allah Hu Akbar 3x ...',
#   1],
#  ['2023-05-10T06:02:21Z',
#   'Bhanyu kuncoro',
#   '@Sumadi ThaihuttuREKAN JEJAK ANIES KAKEK NENEK ARAB ISTRI ARAB MENANTU ARAB  DN PENDUKUNGNYA WAHABI SALAFI HTI FPI DN SEBAGIAN PRIBUMI YG JADI BUDAK MAJIKAN JIKA DEMO SELALU MENGATAKAN POLISI TOHUT INDONESIA NEGARA KAFIR , PENDUKUNG NYA SAMA NEGARANYA SAJA MENGHINA SO PASTINYA JIKA JADI PRESIDEN PANCASILA DI GANTI KHILAFAH POLISI DI GANTI FPI 😄😄 INDONESIA DI GANTI YAMANESIA 😄😄 DAN PRIBUMI YG GK NURUT MAJIKAN DI SWIPING DI PIJAK&quot; DI JADIKAN BUDAK&quot; DI NEGRINYA SENDIRI 😭😭 JIKA INI TERJADI BETOL KATA PAK PRABOWO JIKA TH 2030 INDONESIA HANCUR / HILANG DI GANTI YAMANESIA 😄😄',
#   0],
#  ['2023-05-10T05:14:41Z',
#   'mysyamsir siregar',
#   '@Sumadi Thaihuttu kau mau dijajah / diperbudak / ditindas / dibodohi oleh dajjal kadrun dan nasdrun ... Kalau aku tidak mau faham ... ( KLIK DI GOOGLE , KEMUDIAN KETIK , YAMAN HABIB KOMUNIS YAHUDI ... DAN KAU BACA SEMUANYA , BARU KAU KOMENTAR LAGI OK ... 🇮🇩🇮🇩🇮🇩 Allah Hu Akbar 3x ...',
#   1],
#  ['2023-05-10T05:03:15Z',
#   'Sumadi Thaihuttu',
#   'redaksinya CETAK TEBAL<br>redaksinya MENGARAH KE SESEORANG KANDIDAT<br>redaksinya MENGAJAK dan AJAKAN KEBENCIAN',
#   0],
#  ['2023-05-10T03:38:28Z', 'Gunadi Syarifuddin', 'Cawe cawe.....😆', 0],
#  ['2023-05-10T03:37:53Z',
#   'shasa flower',
#   'JUSUF KALLA BARU NYARIKAN ANIES CAWAPRES .. <br>PADAHAL JK ORANG GOLKAR LHO . KOK GAK PEDULI CAPRES GOLKAR YG DI CALONKAN.  ?<br>TAKUT ANIES KALAH YEEE ...',
#   0],
#  ['2023-05-10T03:37:44Z',
#   'teguh sardjono',
#   'MAHFUD  MD  <br> adalah opsi paling  komplet sebagai sosok  WAPRES dibandingkan dengan nama lain nilai l3bihnya dari .ketokohan , keilmuan , dan pengalaman menjabat sebagai pejabat publik.....  dipasangkan dengan siapapun akan membawa dampak kemenangan',
#   7],
#  ['2023-05-10T04:23:10Z',
#   'Uwe Miskanto',
#   'Akan terlalu mengalahkan capres nya..',
#   0],
#  ['2023-05-10T03:43:33Z', 'Danil Danil 123', 'Sepakat', 1],
#  ['2023-05-10T03:37:08Z',
#   'Langa Langa',
#   'Kata saya d jamin kebenrnya oleh teman tertinggi. Bahwa pa NIS siapa pun wakilnya. Beliau menang.',
#   1],
#  ['2023-05-10T12:07:54Z',
#   'James Bond',
#   'Iya menang juara 3 dpt kompor gas😅',
#   0],
#  ['2023-05-10T03:35:45Z',
#   'Natalius Hulu',
#   'Ganjar/ Mahfud untuk indonesia maju...jauh dari politik identitas..dan memiliki ibu Negara',
#   2],
#  ['2023-05-10T03:35:38Z', 'Siti Sundari', 'Anis Ahy cocok', 0],
#  ['2023-05-10T03:32:52Z',
#   'Abdul Razak Abadi',
#   'ANIS-AHY HARAPAN INDONESIA. SAMA-SAMA CERDAS. SAMA-SAMA BERKOMITMEN UNTUK MENJALANKAN KONSTITUSI SECARA BENAR, KARENA KEDUANYA SAMA-SAMA PAHAM TUJUAN BERNEGARA.',
#   7],
#  ['2023-05-10T05:24:04Z',
#   'Muktohar Gendut',
#   'LOBOTAK GAK WARAS ORANG GILA JABATAN JD TENTARA AJA  PILIH KELUAR BKOKBPENGENBBANGUN NEGARA YA KAYAK ORTUNYA JD KERBODUNGU 😀😀😀😀😀😀',
#   0],
#  ['2023-05-10T03:31:46Z',
#   'SapaR Uddinn',
#   'Pasangan Anis AHY sangat cocok , insyaa&#39;allah terwujud, aamiin...',
#   3],
#  ['2023-05-10T05:50:11Z', 'Andi Purbandi', 'Capres Boneka Capsul.?', 0],
#  ['2023-05-10T05:03:33Z', 'Bunda Ria', 'G bakal alias kosong bloooong', 0],
#  ['2023-05-10T03:30:55Z',
#   'sugeng supriyanto',
#   'PREDIKSI saya, PILPRES 2024 ada 3 CAPRES dengan 2X putaran, dan Di MENANGKAN oleh ANIES BASWEDAN dengan selisih suara, sekitar 4% - 8% suara (Margin of Error 3%)\r<br>.\r<br>\rHanyalah orang yang BUTA HATINYA, yang TIDAK BISA MELIHAT PRESTASI ANIES BASWEDAN di DKI JAKARTA\r<br>Mungkin karena tertutup oleh rasa KEBENCIAN, DENDAM &amp; IRI HATI atau orang yang SALAH dapat INFORMASI &amp; DATA tentang jejak rekam Pak ANIES',
#   1],
#  ['2023-05-10T12:15:01Z',
#   'James Bond',
#   'Semuanya menang cuma anies urutan ke 3 bro😅😅😅',
#   0],
#  ['2023-05-10T03:30:42Z', 'sumardi geger', 'Anis ahy plng ok cocok', 0],
#  ['2023-05-10T03:29:13Z', 'Chairul Salam', '2024', 0],
#  ['2023-05-10T03:28:51Z',
#   'Chairul Salam',
#   'Pemilu. Jurdil. Anis Presiden 2025',
#   0],
#  ['2023-05-10T03:25:42Z',
#   'Muhammad Adil',
#   'Maaf mas, bagi kami rakyat biasa tatap menilai bahwa capres tetap lebih dominan dari pada cawapres',
#   3],
#  ['2023-05-10T07:50:13Z',
#   'Syukron Ismail',
#   'Tentu saja capres lebih dominan. Tetapi dalam hal elektoral cawapres juga berperan apalagi jika dilihat survei ketiga calon mempunyai persentase yang beda tipis. Besar kecilnya pasti cawapres berpengaruh',
#   0],
#  ['2023-05-10T03:23:46Z',
#   'CAPT. K. JOESOEF',
#   'Menurut  saya Cawapres  nggak  begitu significant...tetep  saja Capres nya.yang  menentukan klu bisa Cawapres nya  yang antitesis Capres nya  harus saling   mengisi &amp; kompak...👍🇮🇩💪',
#   3],
#  ['2023-05-10T03:23:15Z',
#   'Novgoz noval',
#   'Isunya sih...Anis, AHY, Mahfudz.',
#   1],
#  ['2023-05-10T03:23:13Z',
#   'Predator',
#   'Set&#39;an merah terus menggaungkan politik identitas Nasakkom PKl untuk meIawan umat islam. Tapi mereka terus berkelip memutar balik fakta untuk menutupi dan mengel&#39;abui agendanya. hal ini seperti strategi mereka dimasa lalu saat 65, memang saat itu Pkl sangat kuat mendominasi dan berkuasa sangat lama..<br><br>Tidak bisa dipungkiri, tidak mungkin mereka dilawan dengan Kons&#39;titusi karena mereka melakukan mani&#39;pulasi secara mazsif terstruktur halus mirip kelic&#39;ikan mereka dimasa lalu<br><br>Mereka totallliter total kontrol, dimana hal hal seperti ini hanya digunakan oleh pemerintahaan yang bersifat komvnisme sangat dikt&#39;ator.<br><br>Apakah kita hanya bisa menerima semua ini yang akan berlangsung sangat lama, apakah kita menerima kita dikendalikan sistim seperti ini. ini sangat berbahaya!! Mereka menghalalkan segala cara dengan buse of power penyalahgunaan kekvasaan.',
#   2],
#  ['2023-05-10T12:27:19Z',
#   'Hasan Nudin',
#   '@James Bond naik kelas dikit...dari dulu bisa begitu doang wkk🤣🤣🤣🤣gx ada isu lain apa',
#   0],
#  ['2023-05-10T12:21:31Z',
#   'James Bond',
#   '@Hasan Nudin jual mayat pasti menang deh😅😅😅',
#   0],
#  ['2023-05-10T05:32:20Z',
#   'Hasan Nudin',
#   '@Sukani43 mana ada sekarang negara khilafah...itukan persepsi dan isu orang yg ketakutan saja...jual ide dan gagasan...bukan lagi jamannya radikal radikul..intoleran atau cerita&quot;basi yg gx ada bukti nya🤣🤣🤣',
#   0],
#  ['2023-05-10T03:40:24Z',
#   'Sukani43',
#   'Pemikiran picik tiada henti sok pandai rubah tu Uudnya pakai kilafah  biar kaya timur teng,di sini  gak berlaku ,UUD 45 harga mati',
#   0],
#  ['2023-05-10T03:22:39Z', 'Hasan afadi Afadi hasan', 'Anis ahy pas mantap', 0],
#  ['2023-05-10T03:20:53Z', 'Faisal Matang', 'Ganjar ahok pasti menang 2024', 0],
#  ['2023-05-10T03:17:51Z', 'ALOY CHANNEL TV', 'Prabowo mahfud cocok nih', 5],
#  ['2023-05-10T08:05:52Z',
#   'Daniel candera Candara',
#   'pa Mahfud, sekilas lebih akrab sama pa Prabowo,',
#   0],
#  ['2023-05-10T03:13:28Z',
#   'Herlina Pongbuntu',
#   'Ganjar Pranowo +Mahfud MD 👍',
#   8],
#  ['2023-05-10T03:11:10Z',
#   'Jumiadi Jumiadi',
#   'Saya semalam bermimpi pak Anis calon president nya sandi aga Uno,,terus Ganjar wakil president nya Ridwan Kamil,,apakah mimpi ini akan terjadi dengan wakil wakil nya Anais dana Ganjar nanti',
#   0],
#  ['2023-05-10T03:05:52Z',
#   'Aries Afvig',
#   'Tahun 2017 Peneliti dari UI memberikan Raport Merah kepada 3 lembaga survey yg metode ilmiah nya sangat tidak jujur :<br>1.Charta politika<br>2.SMRC<br>3.Poltracking',
#   1],
#  ['2023-05-10T03:24:49Z',
#   'CAPT. K. JOESOEF',
#   'LSI   juga  sekarang  jadi ngawur..🤪🐸',
#   0],
#  ['2023-05-10T03:03:25Z',
#   'Kanal Obs99',
#   'RK coba masuk  PAN, bisa diajuin jd cawapres. RK di Golkar di tenggelamkan...kasian',
#   0],
#  ['2023-05-10T03:02:13Z',
#   'Baracuda',
#   'Hanya orang sebagian dan orang awam yang capreskan dan memilih Ganjar. <br>Rekam jejak Ganjar setahun kebelakang sibuk keliling Indonesia bagi2 sembako politik untuk urusan capres padahal Gubernur aktif. Mangkir dan bolos dari tanggung jawab sebagai Gubernur untuk mengurus Jateng dengan banyak permasalahan kritisnya : kemiskinan ekstrim, banjir, jalan2 rusak dan lingkungan. <br>Darimana sumber dana Ganjar bisa sebanyak itu klo bukan dari cukong2 yang menguasai negeri ini?<br>Anehnya sikap over indispliner Ganjar itu gak ada teguran atau sanksi tegas dari Presiden, Menpan RB, Mendagri, DPRD Jateng, Bawaslu, Partainya dll Lembaga terkait.<br>Lihat dua periode kinerja Ganjar Jateng mundur. Sampai Pusat dan Lembaga lain turun tangan membantu selesaikan tugas tanggung jawabnya. <br>Ibarat pelajar sekolah yang pemalas dan gak mampu selesaikan tugas PR nya akhirnya Pak Guru/Ibu Guru dan lainnya sampai ikut membantunya menyelesaikan tugas2nya. <br>Andai Pusat dan Lembaga lain gak turun tangan ikut membantunya entaskan kemiskinan ekstrim di Jateng mungkin sekarang situasinya lebih buruk dari sebelumnya. <br>Lalu figur pemalas dan gak becus seperti Ganjar dicalonkan untuk jadi Presiden RI untuk mengurus Indonesia yang luas ini, mau jadi apaa..! <br>Wlo begitu ada sisi kelebihan Ganjar, bisa jadi kacung pilihan. Gampang2 susah jadi kacung cukong, harus manut perintah tuannya - bukan Negara',
#   0],
#  ['2023-05-10T05:53:21Z',
#   'Bhanyu kuncoro',
#   'Rekan JEJAK ANIES <br><br>KAKEK NENEK ARAB ISTRI ARAB MENANTU ARAB PENDUKUNGNYA WAHABI SALAFI HTI FPI DN PRIBUMI YG JADI BUDAK MAJIKAN SDGKAN PARA PENDUKUNG NYA JIKA DEMO SELALU MENGATAKAN POLISI TOHUT INDONESIA NEGARA KAFIR SEKITAR ANIES JADI PRESIDEN PANCASILA DIGANTI KHILAFAH SWIPING DI MANA&quot; PERPECAHHAN PUN TERJADI SESAMA ANAK BANGSA SALING GEBUK SANA SINI DN YG TERJADI PROPINSI&quot; MAU MERDEKA SENDIRI&quot;  INI BETOL KATA PK PROBOWO TH 2030 INDONESIA HILANG HANCUR<br><br>REKAN JEJAK PRABOWO<br><br>KETURUNAN CINA CAMPUR JAWA MERTUA JAWA PERNAH DI PECAT JADI PANGLIMA KOPASUS DN SATU&quot; NYA PANGLIMA KOPASUS YG DI PECAT PERNAH NYAPRES 3 X MAU KE 4 X ... PRABOWO PRAJURIT HEBAT MAKA BISA LARI KE JORDANIA NYAPRES GAGAL MASUK PEMERINTAH JOKOWI KRENA INGIN BELAJAR MEMEGANG PEMERINTAHAN JIKA JADI PRESIDEN TAK JAUH DARI SOEHARTO/ ORBA YG MANA SIAPA BERANI LAWAN BICARA SIKIT PASTI NYAWA MELAYANG 😄😄',
#   0],
#  ['2023-05-10T03:02:09Z',
#   'Aqidah Harga_Mati',
#   '<b>Bangsa yg Besar ini harus dipimpin oleh orang yg Cerdas Santun dan Beriman,bukan Petugas Partai..</b><br><b>Say_No_Petugas_Partai..</b>',
#   3],
#  ['2023-05-10T07:14:01Z',
#   'Aqidah Harga_Mati',
#   '@IRMAN CHANDRA CHANNEL \xa0 <b>Petugas Partai NO..</b><br><b>Petugas Rakyat YES..</b><br><b>Planga-plongo NO..</b><br><b>Cerdas YES..</b><br><b>Kakek Sugiono NO..</b><br><b>Santun YES..</b><br><b>Tidak percaya Akhirat NO..</b><br><b>Beriman YES..</b><br><b>Genjer-genjer NO..</b><br><b>Agamis YES..</b>',
#   0],
#  ['2023-05-10T03:15:43Z',
#   'IRMAN CHANDRA CHANNEL',
#   'beriman ke yaman....iman jumbo...paloh, jk...wuiiiiihhhh, apalagi yohanes...rusaklah bangsa ini..dari rekam jejak nya',
#   0],
#  ['2023-05-10T03:15:31Z',
#   'Maju Mapan (5758)',
#   'kita pilih capres yang pintar ngomong dan pandai menata kata kata <a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a>',
#   0],
#  ['2023-05-10T02:59:12Z',
#   'James Irenk',
#   'Anies - AHY Pasangan Ideal 2024 - 2029',
#   7],
#  ['2023-05-10T05:29:49Z', 'Agus Sugiarto', 'Sak karepmu...😊', 0],
#  ['2023-05-10T05:21:55Z',
#   'Mukhtar Fauzi',
#   'Saya melihat pasangan anis AHy saya senang, karena akan gampang dikalahkan oleh capres yg ada. Lihat aja nanti',
#   0],
#  ['2023-05-10T04:57:51Z',
#   'Sumadi Thaihuttu',
#   '@Khoirul Anam PELECEHAN ini redaksinya',
#   0],
#  ['2023-05-10T03:27:45Z', 'Khoirul Anam', 'IDEAL SAMA_SAMA BLOOOOON DRUN😂', 0],
#  ['2023-05-10T02:57:43Z',
#   'ucup',
#   'Pengamat bingung , Sopir dan kernet , kernet yg menentukan per jalanan , Koplak tak ,',
#   0],
#  ['2023-05-10T02:56:59Z',
#   'Imam Al gazali',
#   'Aah gk juga ....siapa blng ?????   <br>Yg penting itu ...presidentnya ....lebayyyy amat sih ...',
#   0],
#  ['2023-05-10T02:56:21Z', 'Rc', 'Gw pilih anies &amp; ahy', 3],
#  ['2023-05-10T02:56:04Z',
#   'Khairul Ar-Rasyid',
#   'Anies-Mahfud MD = End Game',
#   3],
#  ['2023-05-10T03:10:06Z',
#   'Pade Onde',
#   'Yg sy tau mahfud menolak anis, saat diskusi dgn deny indrayana, anis ahy mantap juga.',
#   0],
#  ['2023-05-10T02:53:37Z',
#   'Lumadikun dikun',
#   'Bpk ganjar oranowo presiden n bpk mahmud md wakil presiden ok bngt',
#   1],
#  ['2023-05-10T03:04:09Z',
#   'Aqidah Harga_Mati',
#   '<b>Say No To Petugas Partai..</b>',
#   0],
#  ['2023-05-10T02:51:17Z',
#   'Dadang Rohada',
#   'Insya  ALLAH   ANIES   Cawapres  Dengan  Siapa Saja MENANG<br>Dengan  Catatan  Penyelenggara  Pemilu  JURDIL    Penguasa Tidak Intevensi<br>Tidak  Ada  KECURANGAN',
#   5],
#  ['2023-05-10T12:14:16Z', 'James Bond', 'Menang juara 3 dpt kompor gas😅😅😅', 0],
#  ['2023-05-10T06:16:18Z',
#   'Sumadi Thaihuttu',
#   '@Mukhtar Fauzi omong aza kau  sendiri, kok repot',
#   0],
#  ['2023-05-10T05:25:45Z',
#   'Mukhtar Fauzi',
#   'Su udhon aja pikirannya, klau gak mau bertarung gak usah nyalon kok repot',
#   0],
#  ['2023-05-10T05:00:29Z',
#   'Sumadi Thaihuttu',
#   '@Sukani43 aq ga&#39; paham definisi Itoleran ...<br>bisa di beri contoh kah ...<br>biasanya yg mengerti dan mengetik redaksi tersebut pasti paham itu maksudnya ...',
#   0],
#  ['2023-05-10T03:34:54Z',
#   'Sukani43',
#   'Gak mau Anis itoleran ,masarakat gak pada rukun  gara gata kafir',
#   0],
#  ['2023-05-10T02:49:19Z',
#   'Lestary ovicial',
#   'Mahmud md  menang satu putaran pasti',
#   4],
#  ['2023-05-10T03:47:56Z',
#   'Danil Danil 123',
#   'Mahfud MD idola NU &amp; penegak hukum',
#   1],
#  ['2023-05-10T02:47:55Z',
#   'sesilia siruk',
#   'Prabowo sangat tepat kalau disandingkan dengan Prof Dr Mahmud Md karena rakyat sekarang sedang fokus dengan perjuangan Prof Dr Mahmud Md yang berani membongkar kedok di DPR RI KOMISI dan KEMENKEU yang lagi semaraknya KORUPSI dan rakyat sangat mendukung perjuangan Prof Dr Mahmud Md untuk memberantas para perampok uang negara dan rakyat sehingga rakyat sangat respek dan simpatik Prof Dr Mahmud Md menjadi cawapres mendampingi Prabowo Sugianto untuk pimpin NKRI kearah yang lebih maju sejahtera adil dan makmur bagi seluruh rakyat Indonesia karena REKAM JEJAK KINERJA ke 2 tokoh.   ini sangat baik tdk mengecewakan baik presiden sebagai atasan dan rakyat.',
#   7],
#  ['2023-05-10T07:30:17Z', 'Juni 2015', 'Setuju banget', 0],
#  ['2023-05-10T03:05:36Z',
#   'dyan ad',
#   'komentar panjang lebar..tapi mustahil terjadi..cak imin bakal mencak2 krn dia juga ngebet jdi cawapres...<br>belum lagi dulu pas konflik cak imin dg gus dur..mahfudz dikubu gus dur..',
#   1],
#  ['2023-05-10T02:46:13Z',
#   'Baracuda',
#   'Tenggelamkan partai yang mau rubah dasar negara Pancasila jadi Trisila Ekasila.<br>Bravo TNI 🇮🇩<br>Bravo POLRI 🇮🇩',
#   1],
#  ['2023-05-10T02:43:22Z',
#   'Ali Usman',
#   'Saya kira yg berpngruh itu coln prsdennya bukn wakilnya..knpa karna org menilai wakil tidak terllu berpngaruh stlah menang..',
#   0],
#  ['2023-05-10T02:39:50Z',
#   'Gass Poll',
#   'Semua pengamat ternyata analisanya masih dangkal. Karena siapapun wakilnya bila didukung P Jokowi. Sgt berpotensi jadi pemenang. Karena secara fakta pengaruh P Jokowi sampai saat ini sgt kuat.',
#   1],
#  ['2023-05-10T02:39:13Z',
#   'Wayan Aja',
#   'Mahfud MD cocok dampingi Ganjar Pranowo ❤',
#   11],
#  ['2023-05-10T09:05:56Z', 'Achmad Charis', 'Anti pilih boneka partai', 0],
#  ['2023-05-10T08:55:05Z',
#   'Boy Andiek',
#   '@Bhanyu kuncoro Olaah ..koplak ternyta.😂😂,gk liat cil... Wktu ulang thun PDIP ?<br>Gmn bgitu direndahkan....itu presiden indonesia cil bkan presiden partai.😀😀<br><br>Ya gini,klo Mental Simpatisan.mikirnya Pke Emosional,bkan Rasional.<br>Silahkan,lah anda pilih petugas partai...hak anda cil.<br>Gua yg penting gk milih Capres petugas Partai😎😎',
#   0],
#  ['2023-05-10T08:46:43Z',
#   'Bhanyu kuncoro',
#   '@Boy Andiek yang merendahkan itu lawan politiknya Krena cari simpati dgn kata PETUGAS PARTAI ..PETUGAS PARTAI MENUGASKAN KADERNYA YG TERBAIK SIAPA SAJA YG LAYAK SDGKAN PKS NASDEM GK ADA KADER TERBAIK MAKANYA CARI YG BISA DI TUGASKAN DGN PERTIMBANGAN SGLA HAL AGAR PARTAI TAK RUGI DN AHY DI TUGASKAN BAPAKNYA UNTUK MEWAKILI DEMOKRAT SBGI KADER JIKA AHY GK ADA PARTAI YG MAU YA JLN KAKI SENDIRI 😄😄 ALIAS LIHAT&quot; BEGITU PUN ANIES JIKA GAK ADA PARTAI YA JLN KAKI LIHAT&quot; SAHAJA..PDIP..WALAU GK ADA PARTAI YA MASUK BISA MENCALONKAN CAPRES WAPRES SENDIRI KRENA SYARAT 2O PERSEN TERPENUHI 😄😄',
#   0],
#  ['2023-05-10T08:38:32Z',
#   'Bhanyu kuncoro',
#   '@Fahmi Sulton ..milih wapres mesti ada kesepakatan dari partai yg mengusung Nasif ANIES DI USUNG PARTAI JIKA TIDAK MAU JLN KAKI SENDIRI ...PARTAI MENUGASKAN KADERNYA YG TERBAIK..SDGKAN PKS NASDEM MERASA GK ADA KADER TERBAIK MAKANYA MENGUSUNG ANIES DN YG DI USUNG PASTI ADA KERJA SAMA JIKA TIDAK 😄😄 DN MESTI NURUT PERINTAH PARTAI YG MENGUSUNG SDGKAN DEMOKRAT PUNYA KADER AHY MAKANYA IYA MENGUSUNGNYA...PDIP TAK KEKURANGAN KADER TERBAIK DN BUKAN MENGGAMBIL DARI KELUARGANYA SEMISAL ANAKNYA..,YG ADA CONTOH DEMOKRAT MENGGUSUNG ANAKNYA UNTUK DI AJUKAN JADI CAWAPRES  😄😄 GERINDA MENGGUSUNG PRABOWO SENDIRI JADI CAPRES YG MANA PRABOWO JUGA SEBAGAI KETUA PARTAI SELANJUTNYA GERINDA KERJA SAMA DGN PARTAI UNTUK CARI WAPRES..,,PARTAI YG BISA MENGGUSUNG CAPRES WAPRES PDIP KRENA ADA MODAL 20PERSEN SEKIRANYA TIDAK PUNYA MODAL PARTAI HARUS CARI 20PERSEN UNTUK MEMENUHI KOUTA AGAR BISA NYALONKAN CAPRES WAPRES...SEKIRANYA DEMOKRAT GK JADI KERJA SAMA DGN PKS NASDEM MAKA GAGAL SEMUA..DN DEMOKRAT LARI PERGI KE GOLKAR ITU JUGA BISA..',
#   0],
#  ['2023-05-10T08:22:12Z',
#   'Fahmi Sulton',
#   '@Bhanyu kuncoro partai syarat ikut pilpres.. Anggota diusung apapn dn dimanapun sbg anggota partai dhrs nurut ama ketuanya... Berbeda dgn ketua partai.. Ketua tdk ada yg brani main perintah.. Bgtu jg anies.. Dia bkn anggota.. Dia tdk bsa diatur oleh partai manapun tp diajak krjasama.. Makanya anies dilamar dgn ketentuan dia yg milih wapres nya sendiri...',
#   0],
#  ['2023-05-10T02:37:50Z',
#   'INA_Hebat',
#   'Mahfudz paling relefan menghadapi tantangan intolerans dan ketegasan hukum. Dan mengawal program2 yang sudah berjalan terutama ambisi indonesia jd raja batrai kendaraan listrik dunia',
#   4],
#  ['2023-05-10T06:04:53Z', 'INA_Hebat', '@Abdul Razak Abadi raja arab 😁😁😁😁', 0],
#  ['2023-05-10T04:10:12Z',
#   'Abdul Azis Basam',
#   'SANGAT TEPAT BP MAHFUD MD, INSYA ALLAH SIAPAPUN YG MEMILIHNYA PASTI SANGAT BESAR HARAPAN MENANG DLM PILPRES. SAYA YAKIN SE - YAKINNYA, KRN REKAM JEJAKNYA TDK DIRAGUKAN LG DI MATA RAKYAT.',
#   0],
#  ['2023-05-10T03:34:07Z', 'Abdul Razak Abadi', 'Jadi raja utang.', 1],
#  ['2023-05-10T03:08:58Z',
#   'Fahri Bankap',
#   'Setuju Mahfud terbaik di bidang hukum, tp dia harus buktikan sebagai Menkopolhukam selesaikan permasalahan POLITIK UANG pilkada, KKN dalam rekrutmen polisi, kualitas hakim, pencucian uang d kementrian, ketidak Adilan hukum, mengurangi keterbelahan di masyarakat, pilkada dan Pilkades yg jujur,',
#   2],
#  ['2023-05-10T02:35:10Z',
#   'Par Sitalolo',
#   'Cawapres kunci kemenangan pilpres 2024 adalah pendapat pintar tapi kolot dan out to date. Lebih kampungannya lagi adalah penggagas wacana itu mungkin mengadopsi cara hidup kelelawar dan kalong. Taunya makannya bunga yang menyimpan cairan manis.',
#   0],
#  ['2023-05-10T02:33:29Z',
#   'Hery Cahyono',
#   'Serahkan ke anies biar semua jadi wapres semua gak ada yg ditolak.tgupp bisa 75 saat gubernur ,sekarang presiden klu perlu setiap wilayah ada wapresnya anies .kan selalu bikin kejuta anies ,karena bukan pribumi jadi semau maunyalah.',
#   1],
#  ['2023-05-10T02:32:18Z',
#   'Nur Kholis',
#   'Prof mahpud .relizius dn nasionalis, mantap',
#   5],
#  ['2023-05-10T03:44:37Z',
#   'Danil Danil 123',
#   'Kader NU terbaik hanya md md',
#   1],
#  ['2023-05-10T02:28:55Z',
#   'Suwara Pmk',
#   'Prabowo Subianto yg cocok  mendampinginya Insya Allah jadi presiden di antaranya,: habib syech Rizik sihab, jendral Gatot, Sandiago Uno, Mahmud md, Yusuf Kalla. Ingat!!!  jangan ambil dari ketua politik di jamin gagal.',
#   0],
#  ['2023-05-10T02:25:37Z', 'Langit Biru', 'Pengaruh cawapres hanya 1-3% ..', 0],
#  ['2023-05-10T12:13:44Z',
#   'Langit Biru',
#   '@James Bond <br>bisa jadi.. kita lihat aja survei kredibel kedepan',
#   0],
#  ['2023-05-10T12:09:20Z',
#   'James Bond',
#   'Klo persaingannya ketat 1suara aja berpengaruh',
#   0],
#  ['2023-05-10T02:17:25Z',
#   'Brunei Brunei',
#   'Akal busuk presiden ; 3 periode - tunda pemilu - begal demokrat - jegal Anis  semua gagal , lalu kebut ruu tppu  tujuannya jls sasar partai yg bersebrangan dgn presiden',
#   1],
#  ['2023-05-10T02:16:57Z',
#   'dolan',
#   'PAKET KOMPLIT_nya MASA DEPAN INDONESIA!!! <br><br>Mampu meneruskan &amp; Meningkatkan... <br>Masa depannya Indonesia.<br><br>Bpk. Prof. Dr. H. Mohammad Mahfud Mahmodin, S.H., S.U., M.I.P.<br><br>*ROH_nya :<br>Akademisi,<br>Aktivis,<br>Praktisi,<br>Penulis,<br>Politikus,<br>Santri.<br><br>*DARAH_nya :<br>Agamis,<br>Adil, <br>Berani,<br>Jujur,<br>Tegas.<br><br><br>*RAGA_nya :<br>Eksekutif,<br>Legislatif,<br>Yudikatif.',
#   0]]

# %%
#menjadikan dataframe
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'text', 'likeCount'])
df
# Out:
#               publishedAt authorDisplayName  \
# 0    2023-05-10T12:06:58Z       Ahmad Husen
# 1    2023-05-10T12:05:21Z      Ciung Wanara
# 2    2023-05-10T12:05:21Z       Ahmad Husen
# 3    2023-05-10T12:04:48Z         Nisa Nisa
# 4    2023-05-10T11:41:14Z      Deny Saputro
# ..                    ...               ...
# 191  2023-05-10T02:25:37Z       Langit Biru
# 192  2023-05-10T12:13:44Z       Langit Biru
# 193  2023-05-10T12:09:20Z        James Bond
# 194  2023-05-10T02:17:25Z     Brunei Brunei
# 195  2023-05-10T02:16:57Z             dolan
#
#                                                   text  likeCount
# 0    Tapi elit politik seperti cak imin erlangga su...          0
# 1                           Ngabalin cocok untk ganjar          0
# 2    Jika alloh meridhoi kita berharap Prabowo deng...          0
# 3    Setiap kita akan mempertanggung jawabkan pilih...          0
# 4    Siapapun Capresnya, Wakilnya tetap PAK JENDERA...          0
# ..                                                 ...        ...
# 191                    Pengaruh cawapres hanya 1-3% ..          0
# 192  @James Bond <br>bisa jadi.. kita lihat aja sur...          0
# 193     Klo persaingannya ketat 1suara aja berpengaruh          0
# 194  Akal busuk presiden ; 3 periode - tunda pemilu...          1
# 195  PAKET KOMPLIT_nya MASA DEPAN INDONESIA!!! <br>...          0
#
# [196 rows x 4 columns]

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df.to_csv('capres2024.csv', index=False)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### 1. Symbol & Punctuation Removal, case folding
#
# Pada Tahap ini preprocessing yang dilakukan yaitu menghilangkan simbol dan tanda baca, serta melakukan case folding yaitu merubah seluruh huruf yang ada pada data menjadi huruf kecil

# %%
#proses menghilangkan simbol dan emoji
def remove_text_special (text):
  text = text.replace('\\t',"").replace('\\n',"").replace('\\u',"").replace('\\',"")
  text = text.encode('ascii', 'replace').decode('ascii')
  return text.replace("http://"," ").replace("https://", " ")
df['text'] = df['text'].apply(remove_text_special)
print(df['text'])
# Out:
# 0      Tapi elit politik seperti cak imin erlangga su...
# 1                             Ngabalin cocok untk ganjar
# 2      Jika alloh meridhoi kita berharap Prabowo deng...
# 3      Setiap kita akan mempertanggung jawabkan pilih...
# 4      Siapapun Capresnya, Wakilnya tetap PAK JENDERA...
#                              ...
# 191                      Pengaruh cawapres hanya 1-3% ..
# 192    @James Bond <br>bisa jadi.. kita lihat aja sur...
# 193       Klo persaingannya ketat 1suara aja berpengaruh
# 194    Akal busuk presiden ; 3 periode - tunda pemilu...
# 195    PAKET KOMPLIT_nya MASA DEPAN INDONESIA!!! <br>...
# Name: text, Length: 196, dtype: object

# %%
#menghilangkan tanda baca
def remove_tanda_baca(text):
  text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
  return text

df['text'] = df['text'].apply(remove_tanda_baca)
df['text'].head(20)
# Out:
# 0     Tapi elit politik seperti cak imin erlangga su...
# 1                            Ngabalin cocok untk ganjar
# 2     Jika alloh meridhoi kita berharap Prabowo deng...
# 3     Setiap kita akan mempertanggung jawabkan pilih...
# 4     Siapapun Capresnya  Wakilnya tetap PAK JENDERA...
# 5     Siapa capres yg mengganden pak mahfud siap kit...
# 6     BENER JUGA PERKIRAAN KEBANYAKAN MASYARAKAT   b...
# 7     SINGKAT NYA GINI  JANGAN PILIH PETUGAS PARTAI ...
# 8                                Musiknya mantap min
# 9                               ANIES  SAID AQIL SIRADJ
# 10    Probowo vs Mahfud MD  Utk NKRI masa depan supa...
# 11    NU menjaga negeri ini dari keterpecahan  Wajar...
# 12                    GANJAR PRABOWO  br VS br ANIS AHY
# 13    Siapa saja capres yg bergabung dg TGB insaallo...
# 14    Jg pilih dr jawa saja klu dr jawa indo ngak ma...
# 15    Pak Ganjar di dampingi cawapres manapun tetap ...
# 16    Penguasa jg jurang klu Tgb masuk cawapres akan...
# 17    Yang pantas cawapres adalah antara ridwan kami...
# 18                                        Anis Khofifah
# 19                                        Anies ahok
# Name: text, dtype: object

# %%
#proses menghilangkan angka
def remove_numbers (text):
  return re.sub(r"\d+", "", text)
df['text'] = df['text'].apply(remove_numbers)
df['text']
# Out:
# 0      Tapi elit politik seperti cak imin erlangga su...
# 1                             Ngabalin cocok untk ganjar
# 2      Jika alloh meridhoi kita berharap Prabowo deng...
# 3      Setiap kita akan mempertanggung jawabkan pilih...
# 4      Siapapun Capresnya  Wakilnya tetap PAK JENDERA...
#                              ...
# 191                        Pengaruh cawapres hanya
# 192      Bond  br bisa jadi   kita lihat aja survei k...
# 193        Klo persaingannya ketat suara aja berpengaruh
# 194    Akal busuk presiden    periode   tunda pemilu ...
# 195    PAKET KOMPLIT nya MASA DEPAN INDONESIA     br ...
# Name: text, Length: 196, dtype: object

# %%
# proses casefolding
def casefolding(Comment):
  Comment = Comment.lower()
  return Comment
df['text'] = df['text'].apply(casefolding)
df['text']
# Out:
# 0      tapi elit politik seperti cak imin erlangga su...
# 1                             ngabalin cocok untk ganjar
# 2      jika alloh meridhoi kita berharap prabowo deng...
# 3      setiap kita akan mempertanggung jawabkan pilih...
# 4      siapapun capresnya  wakilnya tetap pak jendera...
#                              ...
# 191                        pengaruh cawapres hanya
# 192      bond  br bisa jadi   kita lihat aja survei k...
# 193        klo persaingannya ketat suara aja berpengaruh
# 194    akal busuk presiden    periode   tunda pemilu ...
# 195    paket komplit nya masa depan indonesia     br ...
# Name: text, Length: 196, dtype: object

# %% [markdown]
# ### 2. Tokenizing
# Pada tahap ini preprocessing yang dilakukan adalah tokenizing. Tokenizing adalah metode untuk melakukan pemisahan kata dalam suatu kalimat dengan tujuan untuk proses analisis teks lebih lanjut

# %%
#proses tokenisasi
# from nltk.tokenize import TweetTokenizer
nltk.download('punkt')
# def word_tokenize(text):
#   tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
#   return tokenizer.tokenize(text)

df['review_token'] = df['text'].apply(lambda sentence: nltk.word_tokenize(sentence))
df['review_token']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0      [tapi, elit, politik, seperti, cak, imin, erla...
# 1                        [ngabalin, cocok, untk, ganjar]
# 2      [jika, alloh, meridhoi, kita, berharap, prabow...
# 3      [setiap, kita, akan, mempertanggung, jawabkan,...
# 4      [siapapun, capresnya, wakilnya, tetap, pak, je...
#                              ...
# 191                          [pengaruh, cawapres, hanya]
# 192    [bond, br, bisa, jadi, kita, lihat, aja, surve...
# 193    [klo, persaingannya, ketat, suara, aja, berpen...
# 194    [akal, busuk, presiden, periode, tunda, pemilu...
# 195    [paket, komplit, nya, masa, depan, indonesia, ...
# Name: review_token, Length: 196, dtype: object

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df['review_token'].to_csv('normalisasidata.csv', index=False)

# %% [markdown]
# ### 3. Word Normalization
# Pada tahap ini yang dilakukan yaitu normalisasi pada data. Hal tersebut dilakukan untuk merubah kata yang tidak baku menjadi kata baku

# %%
#Normalisasi kata tidak baku
normalize = pd.read_csv("/content/drive/MyDrive/prosaindata/normalisasidata.csv")

normalize_word_dict = {}

for row in normalize.iterrows():
  if row[0] not in normalize_word_dict:
    normalize_word_dict[row[0]] = row[1]

def normalized_term(comment):
  return [normalize_word_dict[term] if term in normalize_word_dict else term for term in comment]

df['comment_normalize'] = df['review_token'].apply(normalized_term)
df['comment_normalize'].head(20)
# Out:
# 0     [tapi, elit, politik, seperti, cak, imin, erla...
# 1                       [ngabalin, cocok, untk, ganjar]
# 2     [jika, alloh, meridhoi, kita, berharap, prabow...
# 3     [setiap, kita, akan, mempertanggung, jawabkan,...
# 4     [siapapun, capresnya, wakilnya, tetap, pak, je...
# 5     [siapa, capres, yg, mengganden, pak, mahfud, s...
# 6     [bener, juga, perkiraan, kebanyakan, masyaraka...
# 7     [singkat, nya, gini, jangan, pilih, petugas, p...
# 8                               [musiknya, mantap, min]
# 9                           [anies, said, aqil, siradj]
# 10    [probowo, vs, mahfud, md, utk, nkri, masa, dep...
# 11    [nu, menjaga, negeri, ini, dari, keterpecahan,...
# 12             [ganjar, prabowo, br, vs, br, anis, ahy]
# 13    [siapa, saja, capres, yg, bergabung, dg, tgb, ...
# 14    [jg, pilih, dr, jawa, saja, klu, dr, jawa, ind...
# 15    [pak, ganjar, di, dampingi, cawapres, manapun,...
# 16    [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17    [yang, pantas, cawapres, adalah, antara, ridwa...
# 18                                     [anis, khofifah]
# 19                                        [anies, ahok]
# Name: comment_normalize, dtype: object

# %% [markdown]
# ### 4. Stopwords Removal
# Pada tahap ini preprocessing yang dilakukan adalah menghilangkan kata yang tidak penting. Stopwords removal dilakukan 2 kali, yang pertama berdasarkan korpus yang ada di library python yaitu nltk, yang kedua berdasarkan file 'list_stopwords'

# %%
#Stopword Removal
nltk.download('stopwords')
from nltk.corpus import stopwords
txt_stopwords = stopwords.words('indonesian')

def stopwords_removal(filtering) :
  filtering = [word for word in filtering if word not in txt_stopwords]
  return filtering

df['stopwords_removal'] = df['comment_normalize'].apply(stopwords_removal)
df['stopwords_removal'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     [elit, politik, cak, imin, erlangga, susah, ti...
# 1                       [ngabalin, cocok, untk, ganjar]
# 2     [alloh, meridhoi, berharap, prabowo, mafud, md...
# 3     [mempertanggung, jawabkan, pilihan, br, piliha...
# 4       [capresnya, wakilnya, jenderal, fredy, numberi]
# 5     [capres, yg, mengganden, mahfud, dukung, perju...
# 6     [bener, perkiraan, kebanyakan, masyarakat, br,...
# 7     [singkat, nya, gini, pilih, petugas, partai, y...
# 8                               [musiknya, mantap, min]
# 9                           [anies, said, aqil, siradj]
# 10    [probowo, vs, mahfud, md, utk, nkri, negara, a...
# 11    [nu, menjaga, negeri, keterpecahan, wajar, cap...
# 12             [ganjar, prabowo, br, vs, br, anis, ahy]
# 13    [capres, yg, bergabung, dg, tgb, insaalloh, su...
# 14    [jg, pilih, dr, jawa, klu, dr, jawa, indo, nga...
# 15    [ganjar, dampingi, cawapres, manapun, kalah, p...
# 16    [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17             [cawapres, ridwan, kamil, sandiaga, uno]
# 18                                     [anis, khofifah]
# 19                                        [anies, ahok]
# Name: stopwords_removal, dtype: object

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df['stopwords_removal'].to_csv('stopwords1.csv', index=False)

# %%
#stopword removal 2
data_stopwords = pd.read_csv("/content/drive/MyDrive/prosaindata/stopwords1.csv")
print(data_stopwords)

def stopwords_removal2(filter) :
  filter = [word for word in filter if word not in data_stopwords]
  return filter

df['stopwords_removal_final'] = df['stopwords_removal'].apply(stopwords_removal2)
df['stopwords_removal_final'].head(20)
# Out:
#                                      stopwords_removal
# 0    ['elit', 'politik', 'cak', 'imin', 'erlangga',...
# 1              ['ngabalin', 'cocok', 'untk', 'ganjar']
# 2    ['alloh', 'meridhoi', 'berharap', 'prabowo', '...
# 3    ['mempertanggung', 'jawabkan', 'pilihan', 'br'...
# 4    ['capresnya', 'wakilnya', 'jenderal', 'fredy',...
# ..                                                 ...
# 191                           ['pengaruh', 'cawapres']
# 192  ['bond', 'br', 'lihat', 'aja', 'survei', 'kred...
# 193  ['klo', 'persaingannya', 'ketat', 'suara', 'aj...
# 194  ['akal', 'busuk', 'presiden', 'periode', 'tund...
# 195  ['paket', 'komplit', 'nya', 'indonesia', 'br',...
#
# [196 rows x 1 columns]
# 0     [elit, politik, cak, imin, erlangga, susah, ti...
# 1                       [ngabalin, cocok, untk, ganjar]
# 2     [alloh, meridhoi, berharap, prabowo, mafud, md...
# 3     [mempertanggung, jawabkan, pilihan, br, piliha...
# 4       [capresnya, wakilnya, jenderal, fredy, numberi]
# 5     [capres, yg, mengganden, mahfud, dukung, perju...
# 6     [bener, perkiraan, kebanyakan, masyarakat, br,...
# 7     [singkat, nya, gini, pilih, petugas, partai, y...
# 8                               [musiknya, mantap, min]
# 9                           [anies, said, aqil, siradj]
# 10    [probowo, vs, mahfud, md, utk, nkri, negara, a...
# 11    [nu, menjaga, negeri, keterpecahan, wajar, cap...
# 12             [ganjar, prabowo, br, vs, br, anis, ahy]
# 13    [capres, yg, bergabung, dg, tgb, insaalloh, su...
# 14    [jg, pilih, dr, jawa, klu, dr, jawa, indo, nga...
# 15    [ganjar, dampingi, cawapres, manapun, kalah, p...
# 16    [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17             [cawapres, ridwan, kamil, sandiaga, uno]
# 18                                     [anis, khofifah]
# 19                                        [anies, ahok]
# Name: stopwords_removal_final, dtype: object

# %% [markdown]
# ### 5. Stemming
# Pada tahap ini preprocessing yang dilakukan adalah stemming. Stemming adalah proses pemetaan dan penguraian bentuk dari suatu kata menjadi bentuk kata dasarnya.

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.10/dist-packages (1.3.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)

# %%
#proses stem
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import string
import swifter
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming (term):
  return stemmer.stem(term)

term_dict = {}
for document in df['stopwords_removal_final']:
  for term in document:
    if term not in term_dict:
      term_dict[term] = ''

# %%
print(len(term_dict))
print("-----------------------------")
# Out:
# 1238
# -----------------------------

# %%
for term in term_dict:
  term_dict[term] = stemming(term)
  print(term,":",term_dict[term])

print(term_dict)
print("-----------------------------")
# Out:
# elit : elit
# politik : politik
# cak : cak
# imin : imin
# erlangga : erlangga
# susah : susah
# tikat : tikat
# mafud : mafud
# karna : karna
# dah : dah
# busuk : busuk
# ngabalin : ngabalin
# cocok : cocok
# untk : untk
# ganjar : ganjar
# alloh : alloh
# meridhoi : meridhoi
# berharap : harap
# prabowo : prabowo
# md : md
# dukung : dukung
# jokowi : jokowi
# insa : insa
# mempertanggung : tanggung
# jawabkan : jawab
# pilihan : pilih
# br : br
# yg : yg
# pilih : pilih
# amanah : amanah
# jujur : jujur
# adil : adil
# bersyukurlah : syukur
# rakyat : rakyat
# berdusta : dusta
# pendukungnya : dukung
# menanggung : tanggung
# dosa : dosa
# pilihannya : pilih
# menjabat : jabat
# semoga : moga
# allah : allah
# swt : swt
# menolong : tolong
# indonesia : indonesia
# calon : calon
# pendusta : dusta
# aamiin : aamiin
# capresnya : capresnya
# wakilnya : wakil
# jenderal : jenderal
# fredy : fredy
# numberi : numberi
# capres : capres
# mengganden : ganden
# mahfud : mahfud
# perjuangkan : juang
# bener : bener
# perkiraan : kira
# kebanyakan : banyak
# masyarakat : masyarakat
# nyinyirin : nyinyirin
# jusuf : jusuf
# kalla : kalla
# maunya : mau
# pingin : pingin
# wakil : wakil
# presiden : presiden
# emang : emang
# udah : udah
# kali : kali
# wapres : wapres
# singkat : singkat
# nya : nya
# gini : gin
# petugas : tugas
# partai : partai
# hobinya : hobi
# nonton : nonton
# film : film
# p : p
# rno : rno
# jaga : jaga
# kerusakan : rusa
# moral : moral
# musiknya : musik
# mantap : mantap
# min : min
# anies : anies
# said : said
# aqil : aqil
# siradj : siradj
# probowo : probowo
# vs : vs
# utk : utk
# nkri : nkri
# negara : negara
# aman : aman
# makmur : makmur
# dimata : mata
# dunia : dunia
# dihargai : harga
# nu : nu
# menjaga : jaga
# negeri : negeri
# keterpecahan : pecah
# wajar : wajar
# pemersatu : satu
# bangsa : bangsa
# memilih : pilih
# nahdliyin : nahdliyin
# cawapresnya : cawapresnya
# anis : anis
# ahy : ahy
# bergabung : gabung
# dg : dg
# tgb : tgb
# insaalloh : insaalloh
# sukses : sukses
# jg : jg
# dr : dr
# jawa : jawa
# klu : klu
# indo : indo
# ngak : ngak
# maju : maju
# pilihlah : pilih
# berkualitas : kualitas
# mapia : mapia
# cap : cap
# gayung : gayung
# dampingi : damping
# cawapres : cawapres
# manapun : mana
# kalah : kalah
# pdip : pdip
# jago : jago
# handal : handal
# pilpres : pilpres
# moncong : moncong
# putih : putih
# hebat : hebat
# daya : daya
# magnetnya : magnet
# joko : joko
# widodo : widodo
# poles : poles
# model : model
# apapun : apa
# dng : dng
# pencitraan : citra
# elektabilitasnya : elektabilitasnya
# turun : turun
# tahta : tahta
# oposisi : oposisi
# penguasa : kuasa
# jurang : jurang
# masuk : masuk
# tengelam : tengelam
# mucul : mucul
# ridwan : ridwan
# kamil : kamil
# sandiaga : sandiaga
# uno : uno
# khofifah : khofifah
# ahok : ahok
# kunci : kunci
# kemenangan : menang
# garansi : garansi
# menghukum : hukum
# mati : mati
# koruptor : koruptor
# ndak : ndak
# berani : berani
# tukang : tukang
# ngibul : ngibul
# berencana : rencana
# korupsi : korupsi
# erick : erick
# thohir : thohir
# gak : gak
# masok : masok
# penambal : tambal
# namanya : nama
# ban : ban
# serep : serep
# ga : ga
# gs : gs
# sandi : sandi
# salah : salah
# bkn : bkn
# tpi : tpi
# serangan : serang
# fajar : fajar
# aplop : aplop
# mendunia : dunia
# menggemparkan : gempar
# lndonesia : lndonesia
# psnggil : psnggil
# magnit : magnit
# terbukti : bukti
# berduyun : duyun
# mendaftarkan : daftar
# relawan : rawan
# rela : rela
# uang : uang
# mengagumkan : kagum
# ya : ya
# kekuatan : kuat
# murni : murni
# bertegad : bertegad
# perubahan : ubah
# sulit : sulit
# sndaikata : sndaikata
# kpu : kpu
# bawaslu : bawaslu
# mai : mai
# curang : curang
# mengalir : alir
# netral : netral
# tdk : tdk
# berbahaya : bahaya
# juara : juara
# pranowo : pranowo
# halah : halah
# basi : basi
# ujungnye : ujungnye
# erik : erik
# tohir : tohir
# si : si
# anak : anak
# cina : cina
# peranakan : ana
# biji : biji
# peler : peler
# sgt : sgt
# layak : layak
# membawa : bawa
# oke : oke
# gubernur : gubernur
# dki : dki
# karya : karya
# nyata : nyata
# kesepakatan : sepakat
# koalisi : koalisi
# baswedan : baswedan
# hsl : hsl
# jual : jual
# mayat : mayat
# dpt : dpt
# kursi : kursi
# ma : ma
# af : af
# deh : deh
# siroj : siroj
# promosikan : promosi
# orang : orang
# sekeluarga : keluarga
# nyoblos : nyoblos
# nama : nama
# tsb : tsb
# butuh : butuh
# suara : suara
# mempertahankan : tahan
# kemaren : kemaren
# kalo : kalo
# ambil : ambil
# dlu : dlu
# dilabuhkan : labuh
# kinerjanya : kerja
# bagus : bagus
# berhsl : berhsl
# memimpin : pimpin
# teguh : teguh
# pendirian : diri
# plin : plin
# plan : plan
# caplin : caplin
# sibuk : sibuk
# bgt : bgt
# tau : tau
# waras : waras
# muntah : muntah
# makhluk : makhluk
# timur : timur
# kantongnya : kantong
# pkb : pkb
# potensial : potensial
# dipasangkan : pasang
# beliau : beliau
# sederhana : sederhana
# kondisi : kondisi
# intelektual : intelektual
# cerdas : cerdas
# berpengalaman : alam
# birokrasi : birokrasi
# anggota : anggota
# dewan : dewan
# yudikatif : yudikatif
# konstitusi : konstitusi
# thd : thd
# pemberantasan : berantas
# tppu : tppu
# dmkian : dmkian
# sejahtera : sejahtera
# insyaalloh : insyaalloh
# menang : menang
# total : total
# prediksi : prediksi
# pribadi : pribadi
# jarang : jarang
# meleset : meleset
# coba : coba
# nyapres : nyapres
# aja : aja
# lakubpabgak : lakubpabgak
# duet : duet
# wes : wes
# dijamin : jamin
# putaran : putar
# nek : nek
# pengen : ken
# amp : amp
# mahmud : mahmud
# sumut : sumut
# neng : neng
# anne : anne
# bupati : bupati
# purwakarta : purwakarta
# nyalonin : nyalonin
# jd : jd
# kah : kah
# terserah : serah
# bolak : bolak
# males : males
# rame : rame
# lapangan : lapang
# kerja : kerja
# ngurus : ngurus
# kepentingan : penting
# raja : raja
# nganggur : nganggur
# th : th
# seneng : neng
# positif : positif
# bangkrut : bangkrut
# prof : prof
# bolot : bolot
# nurhadi : nurhadi
# serasa : serasa
# gus : gus
# samsudin : samsudin
# kuat : kuat
# kalangan : kalang
# milinium : milinium
# mininimalis : minimal
# z : z
# j : j
# i : i
# pesulap : sulap
# merah : merah
# licik : licik
# aldo : aldo
# dapet : dapet
# kubu : kubu
# rival : rival
# duetnya : duet
# biar : biar
# efek : efek
# elektoral : elektoral
# meremehkan : remeh
# tp : tp
# kualitas : kualitas
# kepemimpinan : pimpin
# uji : uji
# level : level
# mentri : tri
# coblos : coblos
# jgn : jgn
# lupa : lupa
# pk : pk
# subianto : subianto
# terpilih : pilih
# ri : ri
# jatahnya : jatah
# tanda : tanda
# alam : alam
# gp : gp
# mahfudz : mahfudz
# is : is
# the : the
# best : best
# eric : eric
# hanta : hanta
# nggedebuuuuuus : nggedebuuuuuus
# mas : mas
# perobahan : perobahan
# kadrun : kadrun
# benaarr : benaarr
# suci : suci
# takut : takut
# endorse : endorse
# ketawain : ketawain
# cebong : cebong
# sekolam : kolam
# tuuch : tuuch
# ngusung : ngusung
# sbg : sbg
# kelak : kelak
# tuan : tuan
# maha : maha
# putri : putri
# ditengah : tengah
# jalan : jalan
# quot : quot
# menyodok : sodok
# skenarionya : skenario
# sumpah : sumpah
# intro : intro
# takbir : takbir
# allohu : allohu
# akbar : akbar
# gatot : gatot
# nurmantyo : nurmantyo
# nggedabrus : nggedabrus
# hantayuda : hantayuda
# cawaores : cawaores
# kakek : kakek
# sugiono : sugiono
# ideal : ideal
# aah : aah
# musti : musti
# wewenang : wewenang
# dititipkan : titip
# bpk : bpk
# tetaplah : tetap
# wadah : wadah
# komunis : komunis
# pasanga : pasanga
# muda : muda
# pres : pres
# ketum : tum
# demokrat : demokrat
# sby : sby
# pejabat : jabat
# daerah : daerah
# sosok : sosok
# kaya : kaya
# ruf : ruf
# amin : amin
# bicara : bicara
# kinerja : kerja
# indar : indar
# setuju : tuju
# salam : salam
# indobatim : indobatim
# lenbaga : lenbaga
# survei : survei
# mensurvei : survei
# bp : bp
# bond : bond
# oh : oh
# kanpengguna : kanpengguna
# hp : hp
# make : make
# org : org
# dikenal : kenal
# klo : klo
# cilik : cilik
# byk : byk
# blm : blm
# kenal : kenal
# pesanan : pesan
# gx : gx
# pesan : pesan
# ny : ny
# rendah : rendah
# top : top
# pas : pas
# kasihan : kasihan
# kyny : kyny
# doyan : doyan
# berpasangan : pasang
# dgn : dgn
# ps : ps
# diusul : usul
# non : non
# muslim : muslim
# agama : agama
# pintar : pintar
# akhirx : akhirx
# kluar : kluar
# jga : jga
# prediksiku : prediksi
# smua : smua
# rebutanx : rebutanx
# spa : spa
# mndahuluix : mndahuluix
# pling : pling
# bnyak : bnyak
# pndapatan : pndapatan
# suarax : suarax
# krna : krna
# gk : gk
# disuruh : suruh
# sdh : sdh
# jagoan : jago
# dri : dri
# glonganx : glonganx
# psti : psti
# manut : manut
# klw : klw
# bodoh : bodoh
# kemenngan : kemenngan
# ditangan : tang
# golput : golput
# terbaik : baik
# pro : pro
# machfud : machfud
# kecuali : kecuali
# carilah : cari
# kompetensi : kompetensi
# kontribusi : kontribusi
# teruji : uji
# gimana : gimana
# airlangga : airlangga
# bertumpuk : tumpuk
# utang : utang
# boneka : boneka
# dpr : dpr
# sok : sok
# preman : preman
# no : no
# genjer : genjer
# pdi : pdi
# anti : anti
# islam : islam
# munafik : munafik
# dajall : dajall
# cari : cari
# umat : umat
# simpati : simpati
# safari : safari
# identitas : identitas
# ulama : ulama
# pesantren : pesantren
# haram : haram
# laknat : laknat
# azab : azab
# hadeh : hadeh
# bangat : bangat
# kader : kader
# gusdur : gusdur
# krn : krn
# padagang : padagang
# era : era
# pribumi : pribumi
# nasionalis : nasionalis
# tulen : tulen
# wajib : wajib
# hukumnya : hukum
# keturunan : turun
# arab : arab
# yaman : yaman
# selatan : selatan
# merdeka : merdeka
# dijajah : jajah
# diperbudak : budak
# ditindas : tindas
# dibodohi : bodoh
# dajjal : dajjal
# nasdrun : nasdrun
# nusantara : nusantara
# klik : klik
# google : google
# ketik : ketik
# habib : habib
# yahudi : yahudi
# baca : baca
# kau : kau
# ok : ok
# fakta : fakta
# hu : hu
# x : x
# thaihutturekan : thaihutturekan
# jejak : jejak
# nenek : nenek
# istri : istri
# menantu : menantu
# dn : dn
# wahabi : wahabi
# salafi : salaf
# hti : hti
# fpi : fpi
# budak : budak
# majikan : majikan
# demo : demo
# polisi : polisi
# tohut : tohut
# kafir : kafir
# pendukung : dukung
# negaranya : negara
# menghina : hina
# so : so
# pastinya : pasti
# pancasila : pancasila
# ganti : ganti
# khilafah : khilafah
# yamanesia : yamanesia
# nurut : nurut
# swiping : swiping
# pijak : pijak
# jadikan : jadi
# negrinya : negrinya
# betol : betol
# hancur : hancur
# hilang : hilang
# thaihuttu : thaihuttu
# faham : faham
# komentar : komentar
# redaksinya : redaksi
# cetak : cetak
# tebal : tebal
# mengarah : arah
# kandidat : kandidat
# mengajak : ajak
# ajakan : aja
# kebencian : benci
# cawe : cawe
# nyarikan : nyarik
# jk : jk
# golkar : golkar
# lho : lho
# peduli : peduli
# calonkan : calon
# yeee : yeee
# opsi : opsi
# komplet : komplet
# dibandingkan : banding
# nilai : nilai
# lbihnya : lbihnya
# ketokohan : tokoh
# keilmuan : ilmu
# pengalaman : alam
# publik : publik
# dampak : dampak
# mengalahkan : kalah
# sepakat : sepakat
# d : d
# jamin : jamin
# kebenrnya : kebenrnya
# teman : teman
# tertinggi : tinggi
# pa : pa
# nis : nis
# iya : iya
# kompor : kompor
# gas : gas
# memiliki : milik
# harapan : harap
# berkomitmen : komitmen
# menjalankan : jalan
# paham : paham
# tujuan : tuju
# bernegara : negara
# lobotak : lobotak
# gila : gila
# jabatan : jabat
# tentara : tentara
# bkokbpengenbbangun : bkokbpengenbbangun
# kayak : kayak
# ortunya : ortunya
# kerbodungu : kerbodungu
# pasangan : pasang
# insyaa : insyaa
# terwujud : wujud
# capsul : capsul
# g : g
# alias : alias
# kosong : kosong
# bloooong : bloooong
# menangkan : menang
# selisih : selisih
# margin : margin
# of : of
# error : error
# buta : buta
# hatinya : hati
# prestasi : prestasi
# jakarta : jakarta
# tertutup : tutup
# dendam : dendam
# iri : iri
# hati : hati
# informasi : informasi
# data : data
# rekam : rekam
# urutan : urut
# bro : bro
# plng : plng
# pemilu : milu
# jurdil : jurdil
# maaf : maaf
# tatap : tatap
# menilai : nilai
# dominan : dominan
# berperan : peran
# ketiga : tiga
# persentase : persentase
# beda : beda
# tipis : tipis
# kecilnya : kecil
# berpengaruh : pengaruh
# nggak : nggak
# significant : significant
# tetep : tetep
# menentukan : tentu
# antitesis : antitesis
# mengisi : isi
# kompak : kompak
# isunya : isu
# sih : sih
# set : set
# an : an
# menggaungkan : gaung
# nasakkom : nasakkom
# pkl : pkl
# meiawan : meiawan
# berkelip : kelip
# memutar : putar
# menutupi : tutup
# mengel : mengel
# abui : abu
# agendanya : agenda
# strategi : strategi
# dimasa : masa
# mendominasi : dominasi
# berkuasa : kuasa
# dipungkiri : dipungkiri
# dilawan : lawan
# kons : kons
# titusi : titusi
# mani : mani
# pulasi : pulas
# mazsif : mazsif
# terstruktur : struktur
# halus : halus
# kelic : kelic
# ikan : ikan
# totallliter : totallliter
# kontrol : kontrol
# dimana : mana
# pemerintahaan : pemerintahaan
# bersifat : sifat
# komvnisme : komvnisme
# dikt : dikt
# ator : ator
# menerima : terima
# dikendalikan : kendali
# sistim : sistim
# menghalalkan : halal
# buse : buse
# power : power
# penyalahgunaan : penyalahgunaan
# kekvasaan : kekvasaan
# kelas : kelas
# dikit : dikit
# doang : doang
# wkk : wkk
# isu : isu
# nudin : nudin
# itukan : itu
# persepsi : persepsi
# ketakutan : takut
# ide : ide
# gagasan : gagas
# jamannya : jaman
# radikal : radikal
# radikul : radikul
# intoleran : intoleran
# cerita : cerita
# bukti : bukti
# pemikiran : pikir
# picik : picik
# tiada : tiada
# henti : henti
# pandai : pandai
# rubah : rubah
# tu : tu
# uudnya : uudnya
# pakai : pakai
# kilafah : kilafah
# teng : teng
# berlaku : laku
# uud : uud
# harga : harga
# nih : nih
# sekilas : kilas
# akrab : akrab
# semalam : malam
# bermimpi : mimpi
# president : president
# aga : aga
# mimpi : mimpi
# anais : ana
# dana : dana
# peneliti : teliti
# ui : ui
# raport : raport
# lembaga : lembaga
# survey : survey
# metode : metode
# ilmiah : ilmiah
# charta : charta
# politika : politika
# smrc : smrc
# poltracking : poltracking
# lsi : lsi
# ngawur : ngawur
# rk : rk
# pan : pan
# diajuin : diajuin
# tenggelamkan : tenggelam
# kasian : kasi
# awam : awam
# capreskan : capreskan
# setahun : tahun
# kebelakang : belakang
# keliling : keliling
# sembako : sembako
# urusan : urus
# aktif : aktif
# mangkir : mangkir
# bolos : bolos
# tanggung : tanggung
# mengurus : urus
# jateng : jateng
# permasalahan : masalah
# kritisnya : kritis
# kemiskinan : miskin
# ekstrim : ekstrim
# banjir : banjir
# rusak : rusak
# lingkungan : lingkung
# darimana : darimana
# sumber : sumber
# cukong : cukong
# menguasai : kuasa
# anehnya : aneh
# sikap : sikap
# over : over
# indispliner : indispliner
# teguran : tegur
# sanksi : sanksi
# menpan : menpan
# rb : rb
# mendagri : mendagri
# dprd : dprd
# partainya : partai
# dll : dll
# terkait : kait
# lihat : lihat
# periode : periode
# mundur : mundur
# pusat : pusat
# tangan : tangan
# membantu : bantu
# selesaikan : selesai
# tugas : tugas
# pelajar : ajar
# sekolah : sekolah
# pemalas : malas
# pr : pr
# guru : guru
# membantunya : bantu
# menyelesaikan : selesai
# tugasnya : tugas
# andai : andai
# entaskan : entas
# situasinya : situasi
# buruk : buruk
# figur : figur
# becus : becus
# dicalonkan : calon
# luas : luas
# apaa : apaa
# wlo : wlo
# sisi : sisi
# kelebihan : lebih
# kacung : kacung
# gampang : gampang
# perintah : perintah
# tuannya : tuan
# rekan : rekan
# sdgkan : sdgkan
# diganti : ganti
# perpecahhan : perpecahhan
# gebuk : gebuk
# propinsi : propinsi
# campur : campur
# mertua : mertua
# pecat : pecat
# panglima : panglima
# kopasus : kopasus
# prajurit : prajurit
# lari : lari
# jordania : jordania
# gagal : gagal
# pemerintah : perintah
# krena : krena
# belajar : ajar
# memegang : pegang
# pemerintahan : perintah
# soeharto : soeharto
# orba : orba
# lawan : lawan
# sikit : sikit
# nyawa : nyawa
# melayang : layang
# b : b
# dipimpin : pimpin
# santun : santun
# beriman : iman
# say : say
# chandra : chandra
# channel : channel
# yes : yes
# planga : planga
# plongo : plongo
# percaya : percaya
# akhirat : akhirat
# agamis : agam
# iman : iman
# jumbo : jumbo
# paloh : paloh
# wuiiiiihhhh : wuiiiiihhhh
# yohanes : yohanes
# rusaklah : rusak
# ngomong : ngomong
# menata : tata
# a : a
# href : href
# about : about
# invalid : invalid
# zcsafez : zcsafez
# sak : sak
# karepmu : karepmu
# senang : senang
# dikalahkan : kalah
# anam : anam
# pelecehan : leceh
# blooooon : blooooon
# drun : drun
# pengamat : amat
# bingung : bingung
# sopir : sopir
# kernet : kernet
# jalanan : jalan
# koplak : koplak
# blng : blng
# presidentnya : presidentnya
# lebayyyy : lebayyyy
# gw : gw
# end : end
# game : game
# sy : sy
# menolak : tolak
# diskusi : diskusi
# deny : deny
# indrayana : indrayana
# oranowo : oranowo
# n : n
# bngt : bngt
# to : to
# insya : insya
# catatan : catat
# penyelenggara : selenggara
# intevensi : intevensi
# kecurangan : curang
# fauzi : fauzi
# omong : omong
# aza : aza
# repot : repot
# su : su
# udhon : udhon
# pikirannya : pikir
# klau : klau
# bertarung : tarung
# nyalon : nyalon
# aq : aq
# definisi : definisi
# itoleran : itoleran
# contoh : contoh
# mengerti : erti
# mengetik : etik
# redaksi : redaksi
# maksudnya : maksud
# masarakat : masarakat
# rukun : rukun
# gara : gara
# gata : gata
# idola : idola
# penegak : tegak
# hukum : hukum
# disandingkan : sanding
# fokus : fokus
# perjuangan : juang
# membongkar : bongkar
# kedok : kedok
# komisi : komisi
# kemenkeu : kemenkeu
# semaraknya : semarak
# mendukung : dukung
# memberantas : berantas
# perampok : rampok
# respek : respek
# simpatik : simpatik
# mendampingi : damping
# sugianto : sugianto
# pimpin : pimpin
# kearah : arah
# tokoh : tokoh
# mengecewakan : kecewa
# atasan : atas
# banget : banget
# lebar : lebar
# mustahil : mustahil
# mencak : mencak
# ngebet : ngebet
# jdi : jdi
# konflik : konflik
# dur : dur
# dikubu : kubu
# dasar : dasar
# trisila : trisila
# ekasila : ekasila
# bravo : bravo
# tni : tni
# polri : polri
# berpngruh : berpngruh
# coln : coln
# prsdennya : prsdennya
# bukn : bukn
# knpa : knpa
# terllu : terllu
# berpngaruh : berpngaruh
# stlah : stlah
# analisanya : analisanya
# dangkal : dangkal
# didukung : dukung
# berpotensi : potensi
# pemenang : menang
# pengaruh : pengaruh
# kuncoro : kuncoro
# olaah : olaah
# ternyta : ternyta
# liat : liat
# cil : cil
# wktu : wktu
# ulang : ulang
# thun : thun
# gmn : gmn
# bgitu : bgitu
# direndahkan : rendah
# bkan : bkan
# mental : mental
# simpatisan : simpatisan
# mikirnya : mikirnya
# pke : pke
# emosional : emosional
# rasional : rasional
# silahkan : silah
# hak : hak
# gua : gua
# milih : milih
# andiek : andiek
# merendahkan : rendah
# politiknya : politik
# menugaskan : tugas
# kadernya : kader
# pks : pks
# nasdem : nasdem
# tugaskan : tugas
# pertimbangan : timbang
# sgla : sgla
# rugi : rugi
# bapaknya : bapak
# mewakili : wakil
# sbgi : sbgi
# jln : jln
# kaki : kaki
# sahaja : sahaja
# mencalonkan : calon
# syarat : syarat
# o : o
# persen : persen
# terpenuhi : penuh
# sulton : sulton
# mesti : mesti
# mengusung : usung
# nasif : nasif
# usung : usung
# mengusungnya : usung
# kekurangan : kurang
# menggambil : menggambil
# keluarganya : keluarga
# anaknya : anak
# menggusung : menggusung
# ajukan : aju
# gerinda : gerinda
# ketua : ketua
# modal : modal
# memenuhi : penuh
# kouta : kouta
# nyalonkan : nyalonkan
# pergi : pergi
# diusung : usung
# apapn : apapn
# dimanapun : mana
# dhrs : dhrs
# ama : ama
# ketuanya : ketua
# berbeda : beda
# brani : brani
# main : main
# bgtu : bgtu
# bsa : bsa
# diatur : atur
# diajak : ajak
# krjasama : krjasama
# dilamar : lamar
# ketentuan : tentu
# relefan : relefan
# menghadapi : hadap
# tantangan : tantang
# intolerans : intolerans
# ketegasan : tegas
# mengawal : awal
# program : program
# berjalan : jalan
# ambisi : ambisi
# batrai : batrai
# kendaraan : kendara
# listrik : listrik
# razak : razak
# abadi : abadi
# memilihnya : pilih
# dlm : dlm
# yakinnya : yakin
# jejaknya : jejak
# diragukan : ragu
# lg : lg
# mata : mata
# bidang : bidang
# buktikan : bukti
# menkopolhukam : menkopolhukam
# pilkada : pilkada
# kkn : kkn
# rekrutmen : rekrutmen
# hakim : hakim
# pencucian : cuci
# kementrian : tri
# ketidak : tidak
# adilan : adil
# mengurangi : kurang
# keterbelahan : belah
# pilkades : pilkades
# pendapat : dapat
# kolot : kolot
# out : out
# date : date
# kampungannya : kampung
# penggagas : gagas
# wacana : wacana
# mengadopsi : adopsi
# hidup : hidup
# kelelawar : kelelawar
# kalong : kalong
# taunya : tau
# makannya : makan
# bunga : bunga
# menyimpan : simpan
# cairan : cair
# manis : manis
# serahkan : serah
# ditolak : tolak
# tgupp : tgupp
# wilayah : wilayah
# wapresnya : wapresnya
# bikin : bikin
# kejuta : juta
# semau : mau
# maunyalah : mau
# mahpud : mahpud
# relizius : relizius
# mendampinginya : damping
# syech : syech
# rizik : rizik
# sihab : sihab
# jendral : jendral
# sandiago : sandiago
# yusuf : yusuf
# kredibel : kredibel
# kedepan : depan
# persaingannya : saing
# ketat : ketat
# akal : akal
# tunda : tunda
# begal : begal
# jegal : jegal
# kebut : kebut
# ruu : ruu
# tujuannya : tuju
# jls : jls
# sasar : sasar
# bersebrangan : bersebrangan
# paket : paket
# komplit : komplit
# meneruskan : terus
# meningkatkan : tingkat
# depannya : depan
# h : h
# mohammad : mohammad
# mahmodin : mahmodin
# s : s
# u : u
# m : m
# roh : roh
# akademisi : akademisi
# aktivis : aktivis
# praktisi : praktisi
# penulis : tulis
# politikus : politikus
# santri : santri
# darah : darah
# raga : raga
# eksekutif : eksekutif
# legislatif : legislatif
# {'elit': 'elit', 'politik': 'politik', 'cak': 'cak', 'imin': 'imin', 'erlangga': 'erlangga', 'susah': 'susah', 'tikat': 'tikat', 'mafud': 'mafud', 'karna': 'karna', 'dah': 'dah', 'busuk': 'busuk', 'ngabalin': 'ngabalin', 'cocok': 'cocok', 'untk': 'untk', 'ganjar': 'ganjar', 'alloh': 'alloh', 'meridhoi': 'meridhoi', 'berharap': 'harap', 'prabowo': 'prabowo', 'md': 'md', 'dukung': 'dukung', 'jokowi': 'jokowi', 'insa': 'insa', 'mempertanggung': 'tanggung', 'jawabkan': 'jawab', 'pilihan': 'pilih', 'br': 'br', 'yg': 'yg', 'pilih': 'pilih', 'amanah': 'amanah', 'jujur': 'jujur', 'adil': 'adil', 'bersyukurlah': 'syukur', 'rakyat': 'rakyat', 'berdusta': 'dusta', 'pendukungnya': 'dukung', 'menanggung': 'tanggung', 'dosa': 'dosa', 'pilihannya': 'pilih', 'menjabat': 'jabat', 'semoga': 'moga', 'allah': 'allah', 'swt': 'swt', 'menolong': 'tolong', 'indonesia': 'indonesia', 'calon': 'calon', 'pendusta': 'dusta', 'aamiin': 'aamiin', 'capresnya': 'capresnya', 'wakilnya': 'wakil', 'jenderal': 'jenderal', 'fredy': 'fredy', 'numberi': 'numberi', 'capres': 'capres', 'mengganden': 'ganden', 'mahfud': 'mahfud', 'perjuangkan': 'juang', 'bener': 'bener', 'perkiraan': 'kira', 'kebanyakan': 'banyak', 'masyarakat': 'masyarakat', 'nyinyirin': 'nyinyirin', 'jusuf': 'jusuf', 'kalla': 'kalla', 'maunya': 'mau', 'pingin': 'pingin', 'wakil': 'wakil', 'presiden': 'presiden', 'emang': 'emang', 'udah': 'udah', 'kali': 'kali', 'wapres': 'wapres', 'singkat': 'singkat', 'nya': 'nya', 'gini': 'gin', 'petugas': 'tugas', 'partai': 'partai', 'hobinya': 'hobi', 'nonton': 'nonton', 'film': 'film', 'p': 'p', 'rno': 'rno', 'jaga': 'jaga', 'kerusakan': 'rusa', 'moral': 'moral', 'musiknya': 'musik', 'mantap': 'mantap', 'min': 'min', 'anies': 'anies', 'said': 'said', 'aqil': 'aqil', 'siradj': 'siradj', 'probowo': 'probowo', 'vs': 'vs', 'utk': 'utk', 'nkri': 'nkri', 'negara': 'negara', 'aman': 'aman', 'makmur': 'makmur', 'dimata': 'mata', 'dunia': 'dunia', 'dihargai': 'harga', 'nu': 'nu', 'menjaga': 'jaga', 'negeri': 'negeri', 'keterpecahan': 'pecah', 'wajar': 'wajar', 'pemersatu': 'satu', 'bangsa': 'bangsa', 'memilih': 'pilih', 'nahdliyin': 'nahdliyin', 'cawapresnya': 'cawapresnya', 'anis': 'anis', 'ahy': 'ahy', 'bergabung': 'gabung', 'dg': 'dg', 'tgb': 'tgb', 'insaalloh': 'insaalloh', 'sukses': 'sukses', 'jg': 'jg', 'dr': 'dr', 'jawa': 'jawa', 'klu': 'klu', 'indo': 'indo', 'ngak': 'ngak', 'maju': 'maju', 'pilihlah': 'pilih', 'berkualitas': 'kualitas', 'mapia': 'mapia', 'cap': 'cap', 'gayung': 'gayung', 'dampingi': 'damping', 'cawapres': 'cawapres', 'manapun': 'mana', 'kalah': 'kalah', 'pdip': 'pdip', 'jago': 'jago', 'handal': 'handal', 'pilpres': 'pilpres', 'moncong': 'moncong', 'putih': 'putih', 'hebat': 'hebat', 'daya': 'daya', 'magnetnya': 'magnet', 'joko': 'joko', 'widodo': 'widodo', 'poles': 'poles', 'model': 'model', 'apapun': 'apa', 'dng': 'dng', 'pencitraan': 'citra', 'elektabilitasnya': 'elektabilitasnya', 'turun': 'turun', 'tahta': 'tahta', 'oposisi': 'oposisi', 'penguasa': 'kuasa', 'jurang': 'jurang', 'masuk': 'masuk', 'tengelam': 'tengelam', 'mucul': 'mucul', 'ridwan': 'ridwan', 'kamil': 'kamil', 'sandiaga': 'sandiaga', 'uno': 'uno', 'khofifah': 'khofifah', 'ahok': 'ahok', 'kunci': 'kunci', 'kemenangan': 'menang', 'garansi': 'garansi', 'menghukum': 'hukum', 'mati': 'mati', 'koruptor': 'koruptor', 'ndak': 'ndak', 'berani': 'berani', 'tukang': 'tukang', 'ngibul': 'ngibul', 'berencana': 'rencana', 'korupsi': 'korupsi', 'erick': 'erick', 'thohir': 'thohir', 'gak': 'gak', 'masok': 'masok', 'penambal': 'tambal', 'namanya': 'nama', 'ban': 'ban', 'serep': 'serep', 'ga': 'ga', 'gs': 'gs', 'sandi': 'sandi', 'salah': 'salah', 'bkn': 'bkn', 'tpi': 'tpi', 'serangan': 'serang', 'fajar': 'fajar', 'aplop': 'aplop', 'mendunia': 'dunia', 'menggemparkan': 'gempar', 'lndonesia': 'lndonesia', 'psnggil': 'psnggil', 'magnit': 'magnit', 'terbukti': 'bukti', 'berduyun': 'duyun', 'mendaftarkan': 'daftar', 'relawan': 'rawan', 'rela': 'rela', 'uang': 'uang', 'mengagumkan': 'kagum', 'ya': 'ya' ...
# -----------------------------

# %%
def get_stemming(document):
  return [term_dict[term] for term in document]

# %%
df['stemming'] = df['stopwords_removal_final'].swifter.apply(get_stemming)
# Out:
# Pandas Apply:   0%|          | 0/196 [00:00<?, ?it/s]

# %%
print(df['stemming'])
# Out:
# 0      [elit, politik, cak, imin, erlangga, susah, ti...
# 1                        [ngabalin, cocok, untk, ganjar]
# 2      [alloh, meridhoi, harap, prabowo, mafud, md, d...
# 3      [tanggung, jawab, pilih, br, pilih, yg, pilih,...
# 4           [capresnya, wakil, jenderal, fredy, numberi]
#                              ...
# 191                                 [pengaruh, cawapres]
# 192      [bond, br, lihat, aja, survei, kredibel, depan]
# 193            [klo, saing, ketat, suara, aja, pengaruh]
# 194    [akal, busuk, presiden, periode, tunda, milu, ...
# 195    [paket, komplit, nya, indonesia, br, br, terus...
# Name: stemming, Length: 196, dtype: object

# %%
df.head(20)
# Out:
#              publishedAt   authorDisplayName  \
# 0   2023-05-10T12:06:58Z         Ahmad Husen
# 1   2023-05-10T12:05:21Z        Ciung Wanara
# 2   2023-05-10T12:05:21Z         Ahmad Husen
# 3   2023-05-10T12:04:48Z           Nisa Nisa
# 4   2023-05-10T11:41:14Z        Deny Saputro
# 5   2023-05-10T10:46:11Z   ARIEF PRASETYAWAN
# 6   2023-05-10T10:41:24Z        shasa flower
# 7   2023-05-10T10:27:36Z    Pantang menyerah
# 8   2023-05-10T10:03:47Z           Inisial A
# 9   2023-05-10T09:57:03Z             Orna 13
# 10  2023-05-10T09:39:43Z   Buzarman Buzarman
# 11  2023-05-10T09:31:22Z         Danny Rizky
# 12  2023-05-10T09:31:11Z       Agus Yulianto
# 13  2023-05-10T09:07:44Z       sahnun sahnun
# 14  2023-05-10T09:01:53Z       sahnun sahnun
# 15  2023-05-10T08:56:23Z      Slamet Buchori
# 16  2023-05-10T08:49:41Z       sahnun sahnun
# 17  2023-05-10T08:24:30Z  dede ramdan ramdan
# 18  2023-05-10T07:56:42Z      Rita Sumbawati
# 19  2023-05-10T12:19:12Z          James Bond
#
#                                                  text  likeCount  \
# 0   tapi elit politik seperti cak imin erlangga su...          0
# 1                          ngabalin cocok untk ganjar          0
# 2   jika alloh meridhoi kita berharap prabowo deng...          0
# 3   setiap kita akan mempertanggung jawabkan pilih...          0
# 4   siapapun capresnya  wakilnya tetap pak jendera...          0
# 5   siapa capres yg mengganden pak mahfud siap kit...          0
# 6   bener juga perkiraan kebanyakan masyarakat   b...          0
# 7   singkat nya gini  jangan pilih petugas partai ...          0
# 8                              musiknya mantap min             0
# 9                             anies  said aqil siradj          0
# 10  probowo vs mahfud md  utk nkri masa depan supa...          1
# 11  nu menjaga negeri ini dari keterpecahan  wajar...          1
# 12                  ganjar prabowo  br vs br anis ahy          0
# 13  siapa saja capres yg bergabung dg tgb insaallo...          0
# 14  jg pilih dr jawa saja klu dr jawa indo ngak ma...          0
# 15  pak ganjar di dampingi cawapres manapun tetap ...          0
# 16  penguasa jg jurang klu tgb masuk cawapres akan...          0
# 17  yang pantas cawapres adalah antara ridwan kami...          0
# 18                                      anis khofifah          0
# 19                                      anies ahok             0
#
#                                          review_token  \
# 0   [tapi, elit, politik, seperti, cak, imin, erla...
# 1                     [ngabalin, cocok, untk, ganjar]
# 2   [jika, alloh, meridhoi, kita, berharap, prabow...
# 3   [setiap, kita, akan, mempertanggung, jawabkan,...
# 4   [siapapun, capresnya, wakilnya, tetap, pak, je...
# 5   [siapa, capres, yg, mengganden, pak, mahfud, s...
# 6   [bener, juga, perkiraan, kebanyakan, masyaraka...
# 7   [singkat, nya, gini, jangan, pilih, petugas, p...
# 8                             [musiknya, mantap, min]
# 9                         [anies, said, aqil, siradj]
# 10  [probowo, vs, mahfud, md, utk, nkri, masa, dep...
# 11  [nu, menjaga, negeri, ini, dari, keterpecahan,...
# 12           [ganjar, prabowo, br, vs, br, anis, ahy]
# 13  [siapa, saja, capres, yg, bergabung, dg, tgb, ...
# 14  [jg, pilih, dr, jawa, saja, klu, dr, jawa, ind...
# 15  [pak, ganjar, di, dampingi, cawapres, manapun,...
# 16  [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17  [yang, pantas, cawapres, adalah, antara, ridwa...
# 18                                   [anis, khofifah]
# 19                                      [anies, ahok]
#
#                                     comment_normalize  \
# 0   [tapi, elit, politik, seperti, cak, imin, erla...
# 1                     [ngabalin, cocok, untk, ganjar]
# 2   [jika, alloh, meridhoi, kita, berharap, prabow...
# 3   [setiap, kita, akan, mempertanggung, jawabkan,...
# 4   [siapapun, capresnya, wakilnya, tetap, pak, je...
# 5   [siapa, capres, yg, mengganden, pak, mahfud, s...
# 6   [bener, juga, perkiraan, kebanyakan, masyaraka...
# 7   [singkat, nya, gini, jangan, pilih, petugas, p...
# 8                             [musiknya, mantap, min]
# 9                         [anies, said, aqil, siradj]
# 10  [probowo, vs, mahfud, md, utk, nkri, masa, dep...
# 11  [nu, menjaga, negeri, ini, dari, keterpecahan,...
# 12           [ganjar, prabowo, br, vs, br, anis, ahy]
# 13  [siapa, saja, capres, yg, bergabung, dg, tgb, ...
# 14  [jg, pilih, dr, jawa, saja, klu, dr, jawa, ind...
# 15  [pak, ganjar, di, dampingi, cawapres, manapun,...
# 16  [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17  [yang, pantas, cawapres, adalah, antara, ridwa...
# 18                                   [anis, khofifah]
# 19                                      [anies, ahok]
#
#                                     stopwords_removal  \
# 0   [elit, politik, cak, imin, erlangga, susah, ti...
# 1                     [ngabalin, cocok, untk, ganjar]
# 2   [alloh, meridhoi, berharap, prabowo, mafud, md...
# 3   [mempertanggung, jawabkan, pilihan, br, piliha...
# 4     [capresnya, wakilnya, jenderal, fredy, numberi]
# 5   [capres, yg, mengganden, mahfud, dukung, perju...
# 6   [bener, perkiraan, kebanyakan, masyarakat, br,...
# 7   [singkat, nya, gini, pilih, petugas, partai, y...
# 8                             [musiknya, mantap, min]
# 9                         [anies, said, aqil, siradj]
# 10  [probowo, vs, mahfud, md, utk, nkri, negara, a...
# 11  [nu, menjaga, negeri, keterpecahan, wajar, cap...
# 12           [ganjar, prabowo, br, vs, br, anis, ahy]
# 13  [capres, yg, bergabung, dg, tgb, insaalloh, su...
# 14  [jg, pilih, dr, jawa, klu, dr, jawa, indo, nga...
# 15  [ganjar, dampingi, cawapres, manapun, kalah, p...
# 16  [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17           [cawapres, ridwan, kamil, sandiaga, uno]
# 18                                   [anis, khofifah]
# 19                                      [anies, ahok]
#
#                               stopwords_removal_final  \
# 0   [elit, politik, cak, imin, erlangga, susah, ti...
# 1                     [ngabalin, cocok, untk, ganjar]
# 2   [alloh, meridhoi, berharap, prabowo, mafud, md...
# 3   [mempertanggung, jawabkan, pilihan, br, piliha...
# 4     [capresnya, wakilnya, jenderal, fredy, numberi]
# 5   [capres, yg, mengganden, mahfud, dukung, perju...
# 6   [bener, perkiraan, kebanyakan, masyarakat, br,...
# 7   [singkat, nya, gini, pilih, petugas, partai, y...
# 8                             [musiknya, mantap, min]
# 9                         [anies, said, aqil, siradj]
# 10  [probowo, vs, mahfud, md, utk, nkri, negara, a...
# 11  [nu, menjaga, negeri, keterpecahan, wajar, cap...
# 12           [ganjar, prabowo, br, vs, br, anis, ahy]
# 13  [capres, yg, bergabung, dg, tgb, insaalloh, su...
# 14  [jg, pilih, dr, jawa, klu, dr, jawa, indo, nga...
# 15  [ganjar, dampingi, cawapres, manapun, kalah, p...
# 16  [penguasa, jg, jurang, klu, tgb, masuk, cawapr...
# 17           [cawapres, ridwan, kamil, sandiaga, uno]
# 18                                   [anis, khofifah]
# 19                                      [anies, ahok]
#
#                                              stemming
# 0   [elit, politik, cak, imin, erlangga, susah, ti...
# 1                     [ngabalin, cocok, untk, ganjar]
# 2   [alloh, meridhoi, harap, prabowo, mafud, md, d...
# 3   [tanggung, jawab, pilih, br, pilih, yg, pilih,...
# 4        [capresnya, wakil, jenderal, fredy, numberi]
# 5         [capres, yg, ganden, mahfud, dukung, juang]
# 6   [bener, kira, banyak, masyarakat, br, nyinyiri...
# 7   [singkat, nya, gin, pilih, tugas, partai, yg, ...
# 8                                [musik, mantap, min]
# 9                         [anies, said, aqil, siradj]
# 10  [probowo, vs, mahfud, md, utk, nkri, negara, a...
# 11  [nu, jaga, negeri, pecah, wajar, capres, satu,...
# 12           [ganjar, prabowo, br, vs, br, anis, ahy]
# 13   [capres, yg, gabung, dg, tgb, insaalloh, sukses]
# 14  [jg, pilih, dr, jawa, klu, dr, jawa, indo, nga...
# 15  [ganjar, damping, cawapres, mana, kalah, pdip,...
# 16  [kuasa, jg, jurang, klu, tgb, masuk, cawapres,...
# 17           [cawapres, ridwan, kamil, sandiaga, uno]
# 18                                   [anis, khofifah]
# 19                                      [anies, ahok]

# %% [markdown]
# ## Feature Extraction (TF-IDF)

# %%
def joinkata(data):
  kalimat = ""
  for i in data:
    kalimat += i
    kalimat += " "
  return kalimat

text = df['stemming'].swifter.apply(joinkata)
text
# Out:
# Pandas Apply:   0%|          | 0/196 [00:00<?, ?it/s]
# 0      elit politik cak imin erlangga susah tikat maf...
# 1                            ngabalin cocok untk ganjar
# 2      alloh meridhoi harap prabowo mafud md dukung j...
# 3      tanggung jawab pilih br pilih yg pilih amanah ...
# 4                capresnya wakil jenderal fredy numberi
#                              ...
# 191                                   pengaruh cawapres
# 192             bond br lihat aja survei kredibel depan
# 193                  klo saing ketat suara aja pengaruh
# 194    akal busuk presiden periode tunda milu begal d...
# 195    paket komplit nya indonesia br br terus amp ti...
# Name: stemming, Length: 196, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorize document using TF-IDF
tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1)
                        )

# Fit and Transform the documents
X = tfidf.fit_transform(text)

# %%
print(X)
# Out:
#   (0, 146)	0.31621329452572544
#   (0, 187)	0.29866728401409676
#   (0, 433)	0.29866728401409676
#   (0, 556)	0.31621329452572544
#   (0, 993)	0.3409430073935891
#   (0, 940)	0.29866728401409676
#   (0, 259)	0.3409430073935891
#   (0, 347)	0.28505754092655167
#   (0, 151)	0.28505754092655167
#   (0, 768)	0.2369687566133016
#   (0, 249)	0.28505754092655167
#   (1, 280)	0.344285341571776
#   (1, 1040)	0.6029064204677796
#   (1, 179)	0.39303345900350933
#   (1, 657)	0.6029064204677796
#   (2, 355)	0.24023269072015174
#   (2, 401)	0.21277904671477038
#   (2, 238)	0.41245652125917354
#   (2, 597)	0.1382194004484567
#   (2, 778)	0.3006597354908991
#   (2, 324)	0.22928570932336564
#   (2, 612)	0.2742371208107168
#   (2, 31)	0.4804653814403035
#   (2, 556)	0.5086916086986842
#   (3, 1)	0.14594049703574266
#   :	:
#   (195, 1022)	0.06673052477371308
#   (195, 780)	0.06673052477371308
#   (195, 25)	0.06673052477371308
#   (195, 18)	0.06673052477371308
#   (195, 841)	0.06673052477371308
#   (195, 562)	0.06673052477371308
#   (195, 629)	0.06673052477371308
#   (195, 998)	0.06673052477371308
#   (195, 979)	0.06673052477371308
#   (195, 490)	0.06673052477371308
#   (195, 709)	0.06673052477371308
#   (195, 208)	0.06189034127855563
#   (195, 8)	0.06189034127855563
#   (195, 133)	0.058456176436528486
#   (195, 793)	0.05579243123990424
#   (195, 40)	0.050181828099343906
#   (195, 1077)	0.06189034127855563
#   (195, 97)	0.05177584057968336
#   (195, 234)	0.05579243123990424
#   (195, 683)	0.15697493826214026
#   (195, 560)	0.03256339870868994
#   (195, 352)	0.08236756349418825
#   (195, 4)	0.05579243123990424
#   (195, 406)	0.05177584057968336
#   (195, 134)	0.9271932179606615

# %%
df_tfidf = pd.DataFrame(
    X.toarray().T, columns=[f'D{i+1}' for i in range(len(text))], index=tfidf.get_feature_names_out()
)
df_tfidf
# Out:
#             D1   D2   D3        D4   D5        D6   D7        D8   D9  D10  \
# aah        0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# aamiin     0.0  0.0  0.0  0.145940  0.0  0.000000  0.0  0.000000  0.0  0.0
# abadi      0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# abu        0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# adil       0.0  0.0  0.0  0.263123  0.0  0.000000  0.0  0.000000  0.0  0.0
# ...        ...  ...  ...       ...  ...       ...  ...       ...  ...  ...
# yg         0.0  0.0  0.0  0.140689  0.0  0.249535  0.0  0.135608  0.0  0.0
# yohanes    0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# yudikatif  0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# yusuf      0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
# zcsafez    0.0  0.0  0.0  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.0
#
#            ...  D187     D188  D189  D190      D191  D192  D193  D194  \
# aah        ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# aamiin     ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# abadi      ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# abu        ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# adil       ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# ...        ...   ...      ...   ...   ...       ...   ...   ...   ...
# yg         ...   0.0  0.10772   0.0   0.0  0.106456   0.0   0.0   0.0
# yohanes    ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# yudikatif  ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
# yusuf      ...   0.0  0.00000   0.0   0.0  0.238131   0.0   0.0   0.0
# zcsafez    ...   0.0  0.00000   0.0   0.0  0.000000   0.0   0.0   0.0
#
#                D195      D196
# aah        0.000000  0.000000
# aamiin     0.000000  0.000000
# abadi      0.000000  0.000000
# abu        0.000000  0.000000
# adil       0.000000  0.055792
# ...             ...       ...
# yg         0.107657  0.000000
# yohanes    0.000000  0.000000
# yudikatif  0.000000  0.061890
# yusuf      0.000000  0.000000
# zcsafez    0.000000  0.000000
#
# [1080 rows x 196 columns]

# %% [markdown]
# ## Latent Semantic Analysis (LSA)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
# Define the number of topics or components
num_components=10

# Create SVD object
lsa = TruncatedSVD(n_components=num_components, n_iter=100, random_state=42)

# Fit SVD model on data
lsa.fit_transform(X)

# Get Singular values and Components 
Sigma = lsa.singular_values_ 
V_transpose = lsa.components_.T

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()

for index, component in enumerate(lsa.components_):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:5]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['mahfud', 'md', 'ahy', 'anis', 'prabowo']
# Topic 1:  ['ahy', 'anis', 'anies', 'br', 'mantap']
# Topic 2:  ['br', 'yg', 'partai', 'tugas', 'pilih']
# Topic 3:  ['anies', 'juara', 'ahok', 'menang', 'ideal']
# Topic 4:  ['prabowo', 'mahfudz', 'anies', 'airlangga', 'best']
# Topic 5:  ['br', 'ganjar', 'pranowo', 'md', 'vs']
# Topic 6:  ['menang', 'ganjar', 'pranowo', 'wakil', 'ahok']
# Topic 7:  ['mahmud', 'md', 'menang', 'pilih', 'partai']
# Topic 8:  ['ganjar', 'partai', 'pranowo', 'cocok', 'tugas']
# Topic 9:  ['cocok', 'mahmud', 'pilih', 'presiden', 'gatot']
